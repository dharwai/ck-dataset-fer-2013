# %%
import tensorflow
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import tensorflow as tf
# Importing Deep Learning Libraries
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from keras import regularizers
from keras.preprocessing import image

#HISTOGRAM CODE
#histogram code
import matplotlib.pyplot as plt
import os

emotions = ["happy", "sadness", "anger", "disgust", "neutral", "fear", "surprise"]

folder_path = "Jaffetrainvalidation/train"
# Counting the number of images per emotion
counts = [len(os.listdir(os.path.join(folder_path, emotion))) for emotion in emotions]

# Plotting the bar chart
colors = ['red', 'yellow', 'black', 'blue', 'orange', 'green', 'pink']
plt.bar(emotions, height=counts, color=colors)
plt.ylabel('Number')
plt.xlabel('Emotions')


#plt.savefig('hostgoarm.png')
#plt.show()


# Data generators
batch_size = 8

# Data augmentation for training set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Normalization for validation set (no augmentation)
datagen_val = ImageDataGenerator(rescale=1./255)



train_ds = datagen_train.flow_from_directory("Jaffetrainvalidation/train",
                                             target_size=(256, 256),
                                             color_mode="rgb",
                                             batch_size=batch_size,
                                             class_mode='categorical',
                                             shuffle=True)

test_ds = datagen_val.flow_from_directory("Jaffetrainvalidation/validation",
                                         target_size=(256, 256),
                                         color_mode="rgb",
                                         batch_size=batch_size,
                                         class_mode='categorical',
                                         shuffle=False)
print('Train and Validation sets have been created.')


from keras.applications.resnet import ResNet152
conv_base = ResNet152(
    weights='imagenet',
    include_top = False,
    input_shape=(256,256,3)
)


conv_base.summary()


model = Sequential()

model.add(conv_base)
model.add(Flatten())
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))
# Second fully connected layer  
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))

model.add(Dense(7, activation='softmax'))

# model.summary()
# Visualize the model.
#plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

conv_base.trainable = False

model.compile(optimizer = Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

print('CNN model has been created you can proceed to train you data with this model.')




# Training the model
epochs = 500

history = model.fit(x=train_ds,
                    epochs=epochs,
                    validation_data=test_ds)

# Print training history
print(history.history)

# Plotting training history
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# Found 168 images belonging to 7 classes.
# Found 45 images belonging to 7 classes.
# Train and Validation sets have been created.
# Model: "resnet152"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 262, 262, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 128, 128, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 128, 128, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 130, 130, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 64, 64, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 64, 64, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 64, 64, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 64, 64, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 64, 64, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 64, 64, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 32, 32, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 32, 32, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#  conv3_block2_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 32, 32, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 32, 32, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 32, 32, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 32, 32, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 32, 32, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block4_out[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_2_conv[0][0]']
#  rmalization)
#
#  conv3_block5_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_2_bn[0][0]']
#  ation)
#
#  conv3_block5_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block5_2_relu[0][0]']
#  D)
#
#  conv3_block5_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block5_3_conv[0][0]']
#  rmalization)
#
#  conv3_block5_add (Add)      (None, 32, 32, 512)          0         ['conv3_block4_out[0][0]',
#                                                                      'conv3_block5_3_bn[0][0]']
#
#  conv3_block5_out (Activati  (None, 32, 32, 512)          0         ['conv3_block5_add[0][0]']
#  on)
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block5_out[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_2_conv[0][0]']
#  rmalization)
#
#  conv3_block6_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_2_bn[0][0]']
#  ation)
#
#  conv3_block6_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block6_2_relu[0][0]']
#  D)
#
#  conv3_block6_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block6_3_conv[0][0]']
#  rmalization)
#
#  conv3_block6_add (Add)      (None, 32, 32, 512)          0         ['conv3_block5_out[0][0]',
#                                                                      'conv3_block6_3_bn[0][0]']
#
#  conv3_block6_out (Activati  (None, 32, 32, 512)          0         ['conv3_block6_add[0][0]']
#  on)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block6_out[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_2_conv[0][0]']
#  rmalization)
#
#  conv3_block7_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_2_bn[0][0]']
#  ation)
#
#  conv3_block7_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block7_2_relu[0][0]']
#  D)
#
#  conv3_block7_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block7_3_conv[0][0]']
#  rmalization)
#
#  conv3_block7_add (Add)      (None, 32, 32, 512)          0         ['conv3_block6_out[0][0]',
#                                                                      'conv3_block7_3_bn[0][0]']
#
#  conv3_block7_out (Activati  (None, 32, 32, 512)          0         ['conv3_block7_add[0][0]']
#  on)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block7_out[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_2_conv[0][0]']
#  rmalization)
#
#  conv3_block8_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_2_bn[0][0]']
#  ation)
#
#  conv3_block8_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block8_2_relu[0][0]']
#  D)
#
#  conv3_block8_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block8_3_conv[0][0]']
#  rmalization)
#
#  conv3_block8_add (Add)      (None, 32, 32, 512)          0         ['conv3_block7_out[0][0]',
#                                                                      'conv3_block8_3_bn[0][0]']
#
#  conv3_block8_out (Activati  (None, 32, 32, 512)          0         ['conv3_block8_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 256)          131328    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 16, 16, 1024)         525312    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#  conv4_block2_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
# ...
# Epoch 418/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7503 - accuracy: 0.7024 - val_loss: 1.6864 - val_accuracy: 0.4222
# Epoch 419/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9007 - accuracy: 0.6607 - val_loss: 0.9037 - val_accuracy: 0.6000
# Epoch 420/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7770 - accuracy: 0.7321 - val_loss: 0.8916 - val_accuracy: 0.6667
# Epoch 421/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8199 - accuracy: 0.7262 - val_loss: 0.8974 - val_accuracy: 0.7111
# Epoch 422/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8685 - accuracy: 0.7024 - val_loss: 0.7555 - val_accuracy: 0.7111
# Epoch 423/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.7321 - accuracy: 0.7440 - val_loss: 1.0259 - val_accuracy: 0.6222
# Epoch 424/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9195 - accuracy: 0.6726 - val_loss: 1.4929 - val_accuracy: 0.5333
# Epoch 425/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9200 - accuracy: 0.6607 - val_loss: 2.2870 - val_accuracy: 0.5111
# Epoch 426/500
# 21/21 [==============================] - 2s 83ms/step - loss: 1.0774 - accuracy: 0.6190 - val_loss: 1.7864 - val_accuracy: 0.5333
# Epoch 427/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.9202 - accuracy: 0.6369 - val_loss: 2.2400 - val_accuracy: 0.4444
# Epoch 428/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9197 - accuracy: 0.6726 - val_loss: 1.6685 - val_accuracy: 0.5778
# Epoch 429/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8658 - accuracy: 0.6667 - val_loss: 1.6666 - val_accuracy: 0.4889
# Epoch 430/500
# 21/21 [==============================] - 2s 85ms/step - loss: 0.9892 - accuracy: 0.6190 - val_loss: 0.9234 - val_accuracy: 0.6889
# Epoch 431/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.9953 - accuracy: 0.6310 - val_loss: 1.2272 - val_accuracy: 0.5333
# Epoch 432/500
# 21/21 [==============================] - 2s 83ms/step - loss: 1.0669 - accuracy: 0.6071 - val_loss: 1.4373 - val_accuracy: 0.6000
# Epoch 433/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8428 - accuracy: 0.7143 - val_loss: 1.2061 - val_accuracy: 0.5111
# Epoch 434/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9659 - accuracy: 0.6726 - val_loss: 0.9984 - val_accuracy: 0.6000
# Epoch 435/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9746 - accuracy: 0.6369 - val_loss: 0.9961 - val_accuracy: 0.6444
# Epoch 436/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8641 - accuracy: 0.6667 - val_loss: 1.3143 - val_accuracy: 0.5556
# Epoch 437/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9479 - accuracy: 0.6845 - val_loss: 1.4933 - val_accuracy: 0.4889
# Epoch 438/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9667 - accuracy: 0.6488 - val_loss: 1.2682 - val_accuracy: 0.6000
# Epoch 439/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.9500 - accuracy: 0.6845 - val_loss: 1.2000 - val_accuracy: 0.5778
# Epoch 440/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7793 - accuracy: 0.7202 - val_loss: 1.7259 - val_accuracy: 0.5556
# Epoch 441/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8521 - accuracy: 0.6964 - val_loss: 1.2489 - val_accuracy: 0.6667
# Epoch 442/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.7793 - accuracy: 0.7202 - val_loss: 1.6556 - val_accuracy: 0.5333
# Epoch 443/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9548 - accuracy: 0.6667 - val_loss: 1.7268 - val_accuracy: 0.4667
# Epoch 444/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8225 - accuracy: 0.7083 - val_loss: 2.3855 - val_accuracy: 0.3333
# Epoch 445/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8346 - accuracy: 0.6786 - val_loss: 2.1473 - val_accuracy: 0.3556
# Epoch 446/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8187 - accuracy: 0.6726 - val_loss: 1.6651 - val_accuracy: 0.3778
# Epoch 447/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8147 - accuracy: 0.6905 - val_loss: 1.2657 - val_accuracy: 0.5333
# Epoch 448/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9433 - accuracy: 0.6667 - val_loss: 1.2018 - val_accuracy: 0.5778
# Epoch 449/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8353 - accuracy: 0.7024 - val_loss: 1.4006 - val_accuracy: 0.5111
# Epoch 450/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.9294 - accuracy: 0.6429 - val_loss: 0.9906 - val_accuracy: 0.6222
# Epoch 451/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8491 - accuracy: 0.7024 - val_loss: 1.2979 - val_accuracy: 0.5778
# Epoch 452/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9410 - accuracy: 0.6607 - val_loss: 1.2212 - val_accuracy: 0.6222
# Epoch 453/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8384 - accuracy: 0.6964 - val_loss: 0.9285 - val_accuracy: 0.6222
# Epoch 454/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9248 - accuracy: 0.6667 - val_loss: 1.5543 - val_accuracy: 0.4000
# Epoch 455/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8940 - accuracy: 0.6905 - val_loss: 1.2695 - val_accuracy: 0.4889
# Epoch 456/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.9568 - accuracy: 0.5714 - val_loss: 1.3040 - val_accuracy: 0.5556
# Epoch 457/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8645 - accuracy: 0.6964 - val_loss: 1.1375 - val_accuracy: 0.6222
# Epoch 458/500
# 21/21 [==============================] - 2s 83ms/step - loss: 1.0221 - accuracy: 0.6250 - val_loss: 0.8619 - val_accuracy: 0.7556
# Epoch 459/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7813 - accuracy: 0.6905 - val_loss: 0.9015 - val_accuracy: 0.7556
# Epoch 460/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8255 - accuracy: 0.7381 - val_loss: 1.7875 - val_accuracy: 0.4222
# Epoch 461/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9128 - accuracy: 0.6131 - val_loss: 2.5133 - val_accuracy: 0.3556
# Epoch 462/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7975 - accuracy: 0.7083 - val_loss: 1.9804 - val_accuracy: 0.4222
# Epoch 463/500
# 21/21 [==============================] - 2s 83ms/step - loss: 1.0742 - accuracy: 0.6667 - val_loss: 1.2687 - val_accuracy: 0.6444
# Epoch 464/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8065 - accuracy: 0.7083 - val_loss: 1.5884 - val_accuracy: 0.5333
# Epoch 465/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8586 - accuracy: 0.7202 - val_loss: 0.9465 - val_accuracy: 0.7333
# Epoch 466/500
# 21/21 [==============================] - 2s 85ms/step - loss: 0.9231 - accuracy: 0.6667 - val_loss: 1.1805 - val_accuracy: 0.6444
# Epoch 467/500
# 21/21 [==============================] - 2s 81ms/step - loss: 0.8415 - accuracy: 0.7381 - val_loss: 0.9638 - val_accuracy: 0.6222
# Epoch 468/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.7467 - accuracy: 0.7381 - val_loss: 0.8498 - val_accuracy: 0.6667
# Epoch 469/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8970 - accuracy: 0.7024 - val_loss: 1.4662 - val_accuracy: 0.5778
# Epoch 470/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8433 - accuracy: 0.6845 - val_loss: 2.4248 - val_accuracy: 0.4000
# Epoch 471/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9144 - accuracy: 0.6667 - val_loss: 1.0954 - val_accuracy: 0.6444
# Epoch 472/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8751 - accuracy: 0.7321 - val_loss: 1.0955 - val_accuracy: 0.6444
# Epoch 473/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7159 - accuracy: 0.7321 - val_loss: 1.2914 - val_accuracy: 0.5556
# Epoch 474/500
# 21/21 [==============================] - 2s 84ms/step - loss: 1.0482 - accuracy: 0.6845 - val_loss: 1.2016 - val_accuracy: 0.6222
# Epoch 475/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7031 - accuracy: 0.7440 - val_loss: 0.9084 - val_accuracy: 0.6000
# Epoch 476/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9069 - accuracy: 0.6726 - val_loss: 1.0866 - val_accuracy: 0.6000
# Epoch 477/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8370 - accuracy: 0.6607 - val_loss: 0.6961 - val_accuracy: 0.7333
# Epoch 478/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9563 - accuracy: 0.6369 - val_loss: 2.1153 - val_accuracy: 0.4222
# Epoch 479/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9574 - accuracy: 0.6726 - val_loss: 1.6620 - val_accuracy: 0.5333
# Epoch 480/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8749 - accuracy: 0.6726 - val_loss: 0.8148 - val_accuracy: 0.7333
# Epoch 481/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.7277 - accuracy: 0.7083 - val_loss: 1.0712 - val_accuracy: 0.6000
# Epoch 482/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8333 - accuracy: 0.7024 - val_loss: 0.8969 - val_accuracy: 0.7556
# Epoch 483/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7805 - accuracy: 0.7560 - val_loss: 1.6608 - val_accuracy: 0.5333
# Epoch 484/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7593 - accuracy: 0.7262 - val_loss: 0.9620 - val_accuracy: 0.6889
# Epoch 485/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7629 - accuracy: 0.7202 - val_loss: 0.9293 - val_accuracy: 0.7333
# Epoch 486/500
# 21/21 [==============================] - 2s 83ms/step - loss: 1.0315 - accuracy: 0.6607 - val_loss: 1.9164 - val_accuracy: 0.6222
# Epoch 487/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.9135 - accuracy: 0.6488 - val_loss: 1.8546 - val_accuracy: 0.4667
# Epoch 488/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8982 - accuracy: 0.7202 - val_loss: 1.9457 - val_accuracy: 0.5778
# Epoch 489/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8814 - accuracy: 0.6786 - val_loss: 1.1177 - val_accuracy: 0.6222
# Epoch 490/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8396 - accuracy: 0.6905 - val_loss: 0.9324 - val_accuracy: 0.7111
# Epoch 491/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8268 - accuracy: 0.6964 - val_loss: 0.9665 - val_accuracy: 0.7111
# Epoch 492/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8287 - accuracy: 0.6905 - val_loss: 1.9098 - val_accuracy: 0.4444
# Epoch 493/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8841 - accuracy: 0.7143 - val_loss: 1.3234 - val_accuracy: 0.5111
# Epoch 494/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.8186 - accuracy: 0.7143 - val_loss: 1.5963 - val_accuracy: 0.4667
# Epoch 495/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.9278 - accuracy: 0.6607 - val_loss: 1.6794 - val_accuracy: 0.4444
# Epoch 496/500
# 21/21 [==============================] - 2s 85ms/step - loss: 1.0290 - accuracy: 0.6310 - val_loss: 1.7390 - val_accuracy: 0.4667
# Epoch 497/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.7134 - accuracy: 0.7440 - val_loss: 1.5426 - val_accuracy: 0.5333
# Epoch 498/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.7191 - accuracy: 0.7321 - val_loss: 1.3850 - val_accuracy: 0.5556
# Epoch 499/500
# 21/21 [==============================] - 2s 83ms/step - loss: 0.7658 - accuracy: 0.7560 - val_loss: 1.6516 - val_accuracy: 0.6222
# Epoch 500/500
# 21/21 [==============================] - 2s 84ms/step - loss: 0.8335 - accuracy: 0.7262 - val_loss: 2.0287 - val_accuracy: 0.4667
# {'loss': [2.7889246940612793, 2.6482648849487305, 2.676438331604004, 2.3639392852783203, 2.174070119857788, 2.527810573577881, 2.2317698001861572, 2.353250741958618, 2.1915478706359863, 2.224374771118164, 2.138697385787964, 2.2118167877197266, 2.1855669021606445, 2.1854910850524902, 1.9895673990249634, 2.1750195026397705, 1.9797648191452026, 1.9294885396957397, 2.1183581352233887, 1.9812026023864746, 2.0144095420837402, 1.9585689306259155, 1.7222918272018433, 1.786501407623291, 1.843996286392212, 1.977048635482788, 2.0082552433013916, 1.955119013786316, 1.6823348999023438, 1.6722571849822998, 1.7403124570846558, 1.7930558919906616, 1.6491358280181885, 1.8025693893432617, 1.812760829925537, 1.5968457460403442, 1.7774831056594849, 1.7830138206481934, 1.7642326354980469, 1.5561635494232178, 1.7824243307113647, 1.5901843309402466, 1.5922642946243286, 1.574793815612793, 1.6945558786392212, 1.6619207859039307, 1.5105489492416382, 1.6360715627670288, 1.6996536254882812, 1.4942004680633545, 1.7003968954086304, 1.4995015859603882, 1.5658999681472778, 1.4976911544799805, 1.4261620044708252, 1.4051885604858398, 1.567101240158081, 1.5460097789764404, 1.4138782024383545, 1.4308439493179321, 1.3648946285247803, 1.4178175926208496, 1.3803964853286743, 1.3136751651763916, 1.5291376113891602, 1.4411331415176392, 1.388611078262329, 1.3253228664398193, 1.3342576026916504, 1.5037399530410767, 1.5587961673736572, 1.4719526767730713, 1.5237427949905396, 1.4509586095809937, 1.4884119033813477, 1.4014692306518555, 1.3171590566635132, 1.5432287454605103, 1.3931925296783447, 1.3430849313735962, 1.4011406898498535, 1.301849603652954, 1.4832541942596436, 1.2495826482772827, 1.319570779800415, 1.2252064943313599, 1.440308928489685, 1.1991965770721436, 1.336971402168274, 1.4715005159378052, 1.2869762182235718, 1.2655749320983887, 1.3267052173614502, 1.347796082496643, 1.4193404912948608, 1.246930480003357, 1.1301302909851074, 1.3263639211654663, 1.275839924812317, 1.3371398448944092, 1.239316463470459, 1.2253386974334717, 1.2489405870437622, 1.3841378688812256, 1.3203340768814087, 1.3115999698638916, 1.2332141399383545, 1.2390187978744507, 1.2946524620056152, 1.2185512781143188, 1.373045802116394, 1.183990716934204, 1.2419219017028809, 1.0867624282836914, 1.2060514688491821, 1.3193395137786865, 1.2681976556777954, 1.1006207466125488, 1.250438928604126, 1.276413917541504, 1.1904559135437012, 1.3450069427490234, 1.1352357864379883, 1.305403709411621, 1.2828832864761353, 1.0794708728790283, 1.0991319417953491, 1.2012680768966675, 1.3273062705993652, 1.3084402084350586, 1.184380292892456, 1.2405177354812622, 1.1829100847244263, 1.227668285369873, 1.1212238073349, 1.1708494424819946, 1.0404584407806396, 1.2523057460784912, 1.1697630882263184, 1.1549947261810303, 1.1301418542861938, 1.187184453010559, 1.142897367477417, 1.1641292572021484, 1.2237917184829712, 1.2302860021591187, 1.157353162765503, 1.1342273950576782, 1.228424310684204, 1.168867588043213, 1.095777153968811, 1.13430655002594, 1.2535269260406494, 1.1221964359283447, 1.1800092458724976, 1.4173787832260132, 1.0862210988998413, 1.1411994695663452, 1.0781888961791992, 1.1337411403656006, 1.1981152296066284, 1.2168519496917725, 1.1250078678131104, 1.0312899351119995, 1.1678704023361206, 1.2310075759887695, 1.1209137439727783, 1.1868836879730225, 1.0384178161621094, 1.0378831624984741, 1.1185426712036133, 1.0656888484954834, 1.0862876176834106, 1.099674940109253, 1.0084569454193115, 1.131127119064331, 1.012114405632019, 1.106613278388977, 1.076360821723938, 1.0709269046783447, 1.013954758644104, 1.0310884714126587, 1.185741662979126, 0.9468574523925781, 1.145682692527771, 1.000477910041809, 1.027339220046997, 1.120152473449707, 1.138498067855835, 0.9881209135055542, 0.9889200925827026, 1.0097968578338623, 1.1477121114730835, 1.0663561820983887, 1.0755964517593384, 1.1721117496490479, 1.131537914276123, 1.17007315158844, 0.946442723274231, 0.9853803515434265, 1.1322424411773682, 1.2328107357025146, 1.0332 ...
