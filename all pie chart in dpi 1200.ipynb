# %%
#**********ck+ Traning****************

import matplotlib.pyplot as plt

# Assuming you have counts of images for each emotion as 'counts' and emotions list
emotions = ["happy", "sad", "angry", "disgust", "contempt", "fear", "surprise"]
counts = [167, 68, 108, 143, 41, 59, 201]  # Example counts; replace this with your actual counts


# Plotting the pie chart
colors = ['red', 'yellow', 'gray', 'blue', 'orange', 'green', 'pink']
plt.pie(counts, labels=emotions, colors=colors, autopct='%1.1f%%')
plt.title('Emotion Distribution')

# Set a higher DPI for better quality
plt.savefig('cktrain.png', dpi=1200)
plt.show()



#**********ck+ testing****************

import matplotlib.pyplot as plt

# Assuming you have counts of images for each emotion as 'counts' and emotions list
emotions = ["happy", "sad", "angry", "disgust", "contempt", "fear", "surprise"]
counts = [40, 16, 27, 34, 16, 13, 48]  # Example counts; replace this with your actual counts

# Plotting the pie chart
colors = ['red', 'yellow', 'gray', 'blue', 'orange', 'green', 'pink']
plt.pie(counts, labels=emotions, colors=colors, autopct='%1.1f%%')
plt.title('Emotion Distribution')

# Set a higher DPI for better quality
plt.savefig('cktesting.png', dpi=1200)
plt.show()

# %%
#*******************Fair**************************

# %%
########FER 2013 TRANING and testn PIE CHART***********

# %%
########FER 2013 TRANING***********

#FER2013 TRANING

import matplotlib.pyplot as plt

# Assuming you have counts of images for each emotion as 'counts' and emotions list
emotions = ["happy", "sad", "angry", "disgust", "neutral", "fear", "surprise"]
counts = [7215, 4830, 3995, 436, 4965, 4097, 3171]  # Example counts; replace this with your actual counts

# Plotting the pie chart
colors = ['red', 'yellow', 'gray', 'blue', 'orange', 'green', 'pink']
plt.pie(counts, labels=emotions, colors=colors, autopct='%1.1f%%')
plt.title('Emotion Distribution')

# Set a higher DPI for better quality
plt.savefig('fertrain.png', dpi=1200)
plt.show()



#********************************FER2013 Testing**************************

import matplotlib.pyplot as plt

# Assuming you have counts of images for each emotion as 'counts' and emotions list
emotions = ["happy", "sad", "angry", "disgust", "neutral", "fear", "surprise"]
counts = [1775, 1247, 958, 111, 1233, 1024, 831]  # Example counts; replace this with your actual counts
# Plotting the pie chart
colors = ['red', 'yellow', 'gray', 'blue', 'orange', 'green', 'pink']
plt.pie(counts, labels=emotions, colors=colors, autopct='%1.1f%%')
plt.title('Emotion Distribution')

# Set a higher DPI for better quality
plt.savefig('fertest.png', dpi=1200)
plt.show()

# %%
#*******************Fair JAFFE **************************

# %%
########JAFFE TRANING***********

import matplotlib.pyplot as plt

# Assuming you have counts of images for each emotion as 'counts' and emotions list
emotions = ["happy", "sad", "angry", "disgust", "neutral", "fear", "surprise"]
counts = [24, 24, 24, 23, 24, 25, 24]  # Example counts; replace this with your actual counts

# Plotting the pie chart
colors = ['red', 'yellow', 'gray', 'blue', 'orange', 'green', 'pink']
plt.pie(counts, labels=emotions, colors=colors, autopct='%1.1f%%')
plt.title('Emotion Distribution')

# Set a higher DPI for better quality
plt.savefig('JAFFEtrain.png', dpi=1200)
plt.show()





########JAFFE TEST***********

import matplotlib.pyplot as plt

# Assuming you have counts of images for each emotion as 'counts' and emotions list
emotions = ["happy", "sad", "angry", "disgust", "neutral", "fear", "surprise"]
counts = [7, 7, 6, 6, 6, 7, 6]  # Example counts; replace this with your actual counts

# Plotting the pie chart
colors = ['red', 'yellow', 'gray', 'blue', 'orange', 'green', 'pink']
plt.pie(counts, labels=emotions, colors=colors, autopct='%1.1f%%')
plt.title('Emotion Distribution')

# Set a higher DPI for better quality
plt.savefig('JAFFEtEST.png', dpi=1200)
plt.show()
