# %%
import tensorflow
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import tensorflow as tf
# Importing Deep Learning Libraries
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from keras import regularizers
from keras.preprocessing import image

#HISTOGRAM CODE
#histogram code
import matplotlib.pyplot as plt
import os

emotions = ["happy", "sadness", "anger", "disgust", "neutral", "fear", "surprise"]

folder_path = "Jaffetrainvalidation/train"
# Counting the number of images per emotion
counts = [len(os.listdir(os.path.join(folder_path, emotion))) for emotion in emotions]

# Plotting the bar chart
colors = ['red', 'yellow', 'black', 'blue', 'orange', 'green', 'pink']
plt.bar(emotions, height=counts, color=colors)
plt.ylabel('Number')
plt.xlabel('Emotions')


#plt.savefig('hostgoarm.png')
#plt.show()


# Data generators
batch_size = 64

# Data augmentation for training set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Normalization for validation set (no augmentation)
datagen_val = ImageDataGenerator(rescale=1./255)



train_ds = datagen_train.flow_from_directory("Jaffetrainvalidation/train",
                                             target_size=(256, 256),
                                             color_mode="rgb",
                                             batch_size=batch_size,
                                             class_mode='categorical',
                                             shuffle=True)

test_ds = datagen_val.flow_from_directory("Jaffetrainvalidation/validation",
                                         target_size=(256, 256),
                                         color_mode="rgb",
                                         batch_size=batch_size,
                                         class_mode='categorical',
                                         shuffle=False)
print('Train and Validation sets have been created.')


from keras.applications.resnet import ResNet152
conv_base = ResNet152(
    weights='imagenet',
    include_top = False,
    input_shape=(256,256,3)
)


conv_base.summary()


model = Sequential()

model.add(conv_base)
model.add(Flatten())
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))
# Second fully connected layer  
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))

model.add(Dense(7, activation='softmax'))

# model.summary()
# Visualize the model.
#plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

conv_base.trainable = False

model.compile(optimizer = Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

print('CNN model has been created you can proceed to train you data with this model.')




# Training the model
epochs = 500

history = model.fit(x=train_ds,
                    epochs=epochs,
                    validation_data=test_ds)

# Print training history
print(history.history)

# Plotting training history
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# 2024-10-12 08:03:01.822877: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-12 08:03:02.216344: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-12 08:03:03.014746: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 168 images belonging to 7 classes.
# Found 45 images belonging to 7 classes.
# /home/rajesh/anaconda3/lib/python3.11/site-packages/keras/src/preprocessing/image.py:202: UserWarning: Using ".tiff" files with multiple bands will cause distortion. Please verify your output.
#   warnings.warn(
# 2024-10-12 08:03:04.662473: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:04.843053: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:04.843195: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Train and Validation sets have been created.
# 2024-10-12 08:03:04.843967: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:04.844080: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:04.844155: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:05.514731: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:05.514889: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:05.514985: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-12 08:03:05.515069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "resnet152"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 262, 262, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 128, 128, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 128, 128, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 130, 130, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 64, 64, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 64, 64, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 64, 64, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 64, 64, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 64, 64, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 64, 64, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 32, 32, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 32, 32, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 32, 32, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 32, 32, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 32, 32, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 32, 32, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 32, 32, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block4_out[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_2_conv[0][0]']
#  rmalization)
#
#  conv3_block5_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_2_bn[0][0]']
#  ation)
#
#  conv3_block5_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block5_2_relu[0][0]']
#  D)
#
#  conv3_block5_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block5_3_conv[0][0]']
#  rmalization)
#
#  conv3_block5_add (Add)      (None, 32, 32, 512)          0         ['conv3_block4_out[0][0]',
#                                                                      'conv3_block5_3_bn[0][0]']
#
#  conv3_block5_out (Activati  (None, 32, 32, 512)          0         ['conv3_block5_add[0][0]']
#  on)
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block5_out[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_2_conv[0][0]']
#  rmalization)
#
#  conv3_block6_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_2_bn[0][0]']
#  ation)
#
#  conv3_block6_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block6_2_relu[0][0]']
#  D)
#
#  conv3_block6_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block6_3_conv[0][0]']
#  rmalization)
#
#  conv3_block6_add (Add)      (None, 32, 32, 512)          0         ['conv3_block5_out[0][0]',
#                                                                      'conv3_block6_3_bn[0][0]']
#
#  conv3_block6_out (Activati  (None, 32, 32, 512)          0         ['conv3_block6_add[0][0]']
#  on)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block6_out[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_2_conv[0][0]']
#  rmalization)
#
#  conv3_block7_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_2_bn[0][0]']
#  ation)
#
#  conv3_block7_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block7_2_relu[0][0]']
#  D)
#
#  conv3_block7_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block7_3_conv[0][0]']
#  rmalization)
#
#  conv3_block7_add (Add)      (None, 32, 32, 512)          0         ['conv3_block6_out[0][0]',
#                                                                      'conv3_block7_3_bn[0][0]']
#
#  conv3_block7_out (Activati  (None, 32, 32, 512)          0         ['conv3_block7_add[0][0]']
#  on)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block7_out[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_2_conv[0][0]']
#  rmalization)
#
#  conv3_block8_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_2_bn[0][0]']
#  ation)
#
#  conv3_block8_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block8_2_relu[0][0]']
#  D)
#
#  conv3_block8_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block8_3_conv[0][0]']
#  rmalization)
#
#  conv3_block8_add (Add)      (None, 32, 32, 512)          0         ['conv3_block7_out[0][0]',
#                                                                      'conv3_block8_3_bn[0][0]']
#
#  conv3_block8_out (Activati  (None, 32, 32, 512)          0         ['conv3_block8_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 256)          131328    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 16, 16, 1024)         525312    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
# ...
# Epoch 418/500
# 3/3 [==============================] - 2s 670ms/step - loss: 0.4462 - accuracy: 0.8095 - val_loss: 5.1144 - val_accuracy: 0.2222
# Epoch 419/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.5329 - accuracy: 0.7976 - val_loss: 3.2605 - val_accuracy: 0.3333
# Epoch 420/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5249 - accuracy: 0.8274 - val_loss: 2.4515 - val_accuracy: 0.4444
# Epoch 421/500
# 3/3 [==============================] - 2s 499ms/step - loss: 0.4831 - accuracy: 0.8393 - val_loss: 2.0282 - val_accuracy: 0.6000
# Epoch 422/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5549 - accuracy: 0.8214 - val_loss: 1.7704 - val_accuracy: 0.6444
# Epoch 423/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.5618 - accuracy: 0.7976 - val_loss: 1.7928 - val_accuracy: 0.6222
# Epoch 424/500
# 3/3 [==============================] - 2s 666ms/step - loss: 0.4361 - accuracy: 0.8155 - val_loss: 1.8954 - val_accuracy: 0.5556
# Epoch 425/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4517 - accuracy: 0.8274 - val_loss: 1.5023 - val_accuracy: 0.5778
# Epoch 426/500
# 3/3 [==============================] - 2s 657ms/step - loss: 0.4521 - accuracy: 0.8274 - val_loss: 1.5538 - val_accuracy: 0.6222
# Epoch 427/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.5527 - accuracy: 0.8155 - val_loss: 1.5405 - val_accuracy: 0.6889
# Epoch 428/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4782 - accuracy: 0.8095 - val_loss: 1.3901 - val_accuracy: 0.6889
# Epoch 429/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.4772 - accuracy: 0.8095 - val_loss: 1.3130 - val_accuracy: 0.6667
# Epoch 430/500
# 3/3 [==============================] - 2s 661ms/step - loss: 0.5308 - accuracy: 0.7976 - val_loss: 1.1447 - val_accuracy: 0.7333
# Epoch 431/500
# 3/3 [==============================] - 2s 501ms/step - loss: 0.3265 - accuracy: 0.8512 - val_loss: 1.0575 - val_accuracy: 0.6889
# Epoch 432/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5579 - accuracy: 0.7857 - val_loss: 1.0488 - val_accuracy: 0.6444
# Epoch 433/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.3965 - accuracy: 0.8452 - val_loss: 1.0120 - val_accuracy: 0.7111
# Epoch 434/500
# 3/3 [==============================] - 2s 484ms/step - loss: 0.5168 - accuracy: 0.8214 - val_loss: 1.0239 - val_accuracy: 0.7556
# Epoch 435/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.5670 - accuracy: 0.8155 - val_loss: 2.0721 - val_accuracy: 0.4444
# Epoch 436/500
# 3/3 [==============================] - 2s 499ms/step - loss: 0.5560 - accuracy: 0.7738 - val_loss: 5.6639 - val_accuracy: 0.1778
# Epoch 437/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4376 - accuracy: 0.8393 - val_loss: 8.6175 - val_accuracy: 0.1556
# Epoch 438/500
# 3/3 [==============================] - 2s 668ms/step - loss: 0.5209 - accuracy: 0.8095 - val_loss: 8.1992 - val_accuracy: 0.1778
# Epoch 439/500
# 3/3 [==============================] - 2s 663ms/step - loss: 0.5530 - accuracy: 0.8274 - val_loss: 4.8672 - val_accuracy: 0.2000
# Epoch 440/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4417 - accuracy: 0.8155 - val_loss: 2.3500 - val_accuracy: 0.4889
# Epoch 441/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.4626 - accuracy: 0.8512 - val_loss: 2.4438 - val_accuracy: 0.4444
# Epoch 442/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5147 - accuracy: 0.8155 - val_loss: 3.3603 - val_accuracy: 0.3778
# Epoch 443/500
# 3/3 [==============================] - 2s 488ms/step - loss: 0.5273 - accuracy: 0.7619 - val_loss: 3.3015 - val_accuracy: 0.4000
# Epoch 444/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.3940 - accuracy: 0.8571 - val_loss: 3.2552 - val_accuracy: 0.4000
# Epoch 445/500
# 3/3 [==============================] - 2s 665ms/step - loss: 0.4797 - accuracy: 0.7857 - val_loss: 2.4802 - val_accuracy: 0.5778
# Epoch 446/500
# 3/3 [==============================] - 2s 672ms/step - loss: 0.4180 - accuracy: 0.8333 - val_loss: 1.7638 - val_accuracy: 0.6667
# Epoch 447/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4463 - accuracy: 0.8452 - val_loss: 1.5595 - val_accuracy: 0.7111
# Epoch 448/500
# 3/3 [==============================] - 2s 508ms/step - loss: 0.5101 - accuracy: 0.8214 - val_loss: 1.7367 - val_accuracy: 0.6222
# Epoch 449/500
# 3/3 [==============================] - 2s 505ms/step - loss: 0.5657 - accuracy: 0.7917 - val_loss: 1.9367 - val_accuracy: 0.6222
# Epoch 450/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5431 - accuracy: 0.7619 - val_loss: 2.0493 - val_accuracy: 0.6444
# Epoch 451/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.5001 - accuracy: 0.8274 - val_loss: 1.9142 - val_accuracy: 0.6444
# Epoch 452/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.3839 - accuracy: 0.8750 - val_loss: 1.9632 - val_accuracy: 0.6222
# Epoch 453/500
# 3/3 [==============================] - 2s 667ms/step - loss: 0.4225 - accuracy: 0.8512 - val_loss: 2.2955 - val_accuracy: 0.6000
# Epoch 454/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.4026 - accuracy: 0.8571 - val_loss: 2.5736 - val_accuracy: 0.5556
# Epoch 455/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.5062 - accuracy: 0.8274 - val_loss: 2.4404 - val_accuracy: 0.5556
# Epoch 456/500
# 3/3 [==============================] - 2s 666ms/step - loss: 0.5228 - accuracy: 0.8274 - val_loss: 2.5857 - val_accuracy: 0.4222
# Epoch 457/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.3692 - accuracy: 0.8393 - val_loss: 2.8385 - val_accuracy: 0.3778
# Epoch 458/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5482 - accuracy: 0.7857 - val_loss: 2.6633 - val_accuracy: 0.4000
# Epoch 459/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.5503 - accuracy: 0.8036 - val_loss: 1.8025 - val_accuracy: 0.4889
# Epoch 460/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4840 - accuracy: 0.8095 - val_loss: 1.3068 - val_accuracy: 0.6444
# Epoch 461/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4819 - accuracy: 0.8095 - val_loss: 1.1719 - val_accuracy: 0.7111
# Epoch 462/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.3453 - accuracy: 0.8690 - val_loss: 1.2094 - val_accuracy: 0.7333
# Epoch 463/500
# 3/3 [==============================] - 2s 673ms/step - loss: 0.5282 - accuracy: 0.8155 - val_loss: 1.1936 - val_accuracy: 0.7556
# Epoch 464/500
# 3/3 [==============================] - 2s 657ms/step - loss: 0.5118 - accuracy: 0.8333 - val_loss: 1.4285 - val_accuracy: 0.7111
# Epoch 465/500
# 3/3 [==============================] - 2s 664ms/step - loss: 0.4869 - accuracy: 0.8095 - val_loss: 1.4989 - val_accuracy: 0.6889
# Epoch 466/500
# 3/3 [==============================] - 2s 673ms/step - loss: 0.5239 - accuracy: 0.7798 - val_loss: 1.3470 - val_accuracy: 0.6889
# Epoch 467/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.4874 - accuracy: 0.8274 - val_loss: 1.1209 - val_accuracy: 0.8000
# Epoch 468/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.4716 - accuracy: 0.8214 - val_loss: 1.3590 - val_accuracy: 0.7556
# Epoch 469/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.4565 - accuracy: 0.8393 - val_loss: 2.2092 - val_accuracy: 0.5111
# Epoch 470/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.4308 - accuracy: 0.8155 - val_loss: 2.7106 - val_accuracy: 0.4667
# Epoch 471/500
# 3/3 [==============================] - 2s 671ms/step - loss: 0.4371 - accuracy: 0.8155 - val_loss: 2.5347 - val_accuracy: 0.5333
# Epoch 472/500
# 3/3 [==============================] - 2s 500ms/step - loss: 0.4503 - accuracy: 0.8393 - val_loss: 2.7631 - val_accuracy: 0.4889
# Epoch 473/500
# 3/3 [==============================] - 2s 532ms/step - loss: 0.5079 - accuracy: 0.8155 - val_loss: 3.0801 - val_accuracy: 0.5111
# Epoch 474/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.3649 - accuracy: 0.8690 - val_loss: 3.4190 - val_accuracy: 0.5333
# Epoch 475/500
# 3/3 [==============================] - 2s 543ms/step - loss: 0.5129 - accuracy: 0.8036 - val_loss: 3.5871 - val_accuracy: 0.5333
# Epoch 476/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4362 - accuracy: 0.8631 - val_loss: 3.5914 - val_accuracy: 0.5111
# Epoch 477/500
# 3/3 [==============================] - 2s 498ms/step - loss: 0.4616 - accuracy: 0.8571 - val_loss: 3.5742 - val_accuracy: 0.4667
# Epoch 478/500
# 3/3 [==============================] - 2s 662ms/step - loss: 0.3915 - accuracy: 0.8631 - val_loss: 3.0576 - val_accuracy: 0.4889
# Epoch 479/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5052 - accuracy: 0.8214 - val_loss: 2.9529 - val_accuracy: 0.5111
# Epoch 480/500
# 3/3 [==============================] - 2s 484ms/step - loss: 0.4314 - accuracy: 0.8333 - val_loss: 2.7423 - val_accuracy: 0.5333
# Epoch 481/500
# 3/3 [==============================] - 2s 499ms/step - loss: 0.3588 - accuracy: 0.8690 - val_loss: 2.1705 - val_accuracy: 0.5778
# Epoch 482/500
# 3/3 [==============================] - 2s 482ms/step - loss: 0.4406 - accuracy: 0.8393 - val_loss: 1.7677 - val_accuracy: 0.6000
# Epoch 483/500
# 3/3 [==============================] - 2s 663ms/step - loss: 0.4166 - accuracy: 0.8452 - val_loss: 1.6236 - val_accuracy: 0.6444
# Epoch 484/500
# 3/3 [==============================] - 2s 509ms/step - loss: 0.4884 - accuracy: 0.8214 - val_loss: 1.4003 - val_accuracy: 0.6667
# Epoch 485/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.4439 - accuracy: 0.8274 - val_loss: 1.1429 - val_accuracy: 0.6889
# Epoch 486/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.5109 - accuracy: 0.8393 - val_loss: 1.3901 - val_accuracy: 0.6444
# Epoch 487/500
# 3/3 [==============================] - 2s 668ms/step - loss: 0.3464 - accuracy: 0.8512 - val_loss: 2.8758 - val_accuracy: 0.4889
# Epoch 488/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.3861 - accuracy: 0.8631 - val_loss: 4.0847 - val_accuracy: 0.4000
# Epoch 489/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4505 - accuracy: 0.8393 - val_loss: 4.1358 - val_accuracy: 0.4000
# Epoch 490/500
# 3/3 [==============================] - 2s 501ms/step - loss: 0.5399 - accuracy: 0.7976 - val_loss: 613.4631 - val_accuracy: 0.1556
# Epoch 491/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4830 - accuracy: 0.7857 - val_loss: 100.1071 - val_accuracy: 0.1556
# Epoch 492/500
# 3/3 [==============================] - 2s 661ms/step - loss: 0.4350 - accuracy: 0.8333 - val_loss: 42.9741 - val_accuracy: 0.1556
# Epoch 493/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.5038 - accuracy: 0.7917 - val_loss: 26.7262 - val_accuracy: 0.3333
# Epoch 494/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.4495 - accuracy: 0.8512 - val_loss: 21.6525 - val_accuracy: 0.4000
# Epoch 495/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4925 - accuracy: 0.8512 - val_loss: 17.5017 - val_accuracy: 0.4222
# Epoch 496/500
# 3/3 [==============================] - 2s 488ms/step - loss: 0.5946 - accuracy: 0.7976 - val_loss: 14.6435 - val_accuracy: 0.4000
# Epoch 497/500
# 3/3 [==============================] - 2s 498ms/step - loss: 0.4716 - accuracy: 0.8095 - val_loss: 10.2020 - val_accuracy: 0.4000
# Epoch 498/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.5978 - accuracy: 0.7917 - val_loss: 6.9016 - val_accuracy: 0.4222
# Epoch 499/500
# 3/3 [==============================] - 2s 659ms/step - loss: 0.3365 - accuracy: 0.8452 - val_loss: 4.9595 - val_accuracy: 0.5111
# Epoch 500/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.4884 - accuracy: 0.8452 - val_loss: 4.4363 - val_accuracy: 0.5778
# {'loss': [2.836182117462158, 2.7632288932800293, 2.476482629776001, 2.2204270362854004, 2.4022154808044434, 2.2978718280792236, 2.1848950386047363, 2.323333740234375, 2.4449288845062256, 2.0000216960906982, 1.9883321523666382, 2.0587711334228516, 2.0118823051452637, 1.8490831851959229, 2.0253560543060303, 1.684236764907837, 2.0662481784820557, 2.0786550045013428, 1.9459664821624756, 1.7151881456375122, 1.9043076038360596, 1.8268076181411743, 1.8382501602172852, 1.6723049879074097, 1.7770215272903442, 1.8133302927017212, 1.7773971557617188, 1.6765556335449219, 1.805676817893982, 1.670161485671997, 1.6151529550552368, 1.696412205696106, 1.643000602722168, 1.5384714603424072, 1.7229326963424683, 1.6256508827209473, 1.5939146280288696, 1.5196304321289062, 1.3247724771499634, 1.4821653366088867, 1.5944709777832031, 1.4793015718460083, 1.5484869480133057, 1.4573434591293335, 1.28566312789917, 1.5090854167938232, 1.3007146120071411, 1.4061570167541504, 1.511049509048462, 1.4272302389144897, 1.3830572366714478, 1.3513330221176147, 1.3044513463974, 1.332478642463684, 1.4211095571517944, 1.1971464157104492, 1.0618013143539429, 1.2131693363189697, 1.1652984619140625, 1.2397592067718506, 1.2565371990203857, 1.3765085935592651, 1.1943124532699585, 1.43141770362854, 1.275864601135254, 1.1741529703140259, 1.1859714984893799, 1.2853566408157349, 1.2031903266906738, 1.1782920360565186, 1.1035163402557373, 1.1065915822982788, 1.2585645914077759, 1.1009670495986938, 1.1413027048110962, 1.0981279611587524, 1.1060459613800049, 1.1040434837341309, 1.2050851583480835, 1.1950583457946777, 1.1041713953018188, 0.9534979462623596, 1.168792486190796, 1.0743365287780762, 1.235169529914856, 1.1120351552963257, 1.055786371231079, 0.9864356517791748, 1.195604920387268, 1.0325067043304443, 0.9910245537757874, 0.9866389036178589, 1.2060511112213135, 1.0002473592758179, 1.128809928894043, 1.112877607345581, 0.9941515326499939, 1.2580525875091553, 1.1716018915176392, 1.1496797800064087, 0.9627009034156799, 0.9408616423606873, 1.1082231998443604, 1.096222162246704, 1.1047104597091675, 0.9480244517326355, 1.0086395740509033, 0.8778361082077026, 0.9899779558181763, 1.039748191833496, 1.0496104955673218, 1.0911439657211304, 0.9940866827964783, 1.0026309490203857, 0.98138427734375, 0.8717876672744751, 0.8921675682067871, 0.9018582105636597, 0.7205541133880615, 1.0404455661773682, 0.954198956489563, 0.8973855376243591, 0.9760676622390747, 0.9042525291442871, 0.8277542591094971, 0.943142294883728, 0.801996111869812, 0.9833950996398926, 0.8770611882209778, 0.9575394988059998, 0.8980664610862732, 1.0128997564315796, 0.9336511492729187, 0.879330575466156, 0.918346107006073, 0.833832323551178, 0.8310917615890503, 0.9073850512504578, 0.8612639904022217, 0.9627360105514526, 0.8849844932556152, 0.7801758646965027, 0.8566218614578247, 1.1322309970855713, 0.7468990683555603, 0.7809016108512878, 0.9054387211799622, 0.7531756162643433, 0.8730769157409668, 0.853550136089325, 0.8214154839515686, 0.7900470495223999, 0.7713071703910828, 0.9573960304260254, 0.9066696166992188, 0.7919920682907104, 0.7278084754943848, 0.8662260174751282, 0.7678106427192688, 0.8485410809516907, 0.8699560761451721, 0.8397700786590576, 0.7084782719612122, 0.7665932178497314, 0.8065209984779358, 0.8538121581077576, 0.7853823304176331, 0.9589885473251343, 0.8159581422805786, 0.7680620551109314, 0.7603316307067871, 0.9127736687660217, 0.8358374238014221, 0.7354996204376221, 0.8085508942604065, 0.792907178401947, 0.8142881989479065, 0.8406249284744263, 0.8435342907905579, 0.7091162800788879, 0.6907719373703003, 0.6062645316123962, 0.8551873564720154, 0.7599402666091919, 0.7675410509109497, 0.7554382085800171, 0.8823294639587402, 0.7106192708015442, 0.8199726343154907, 0.8171123266220093, 0.766697108745575, 0.6811097264289856, 0.7791144251823425, 0.8122028112411499, 0.6991440653800964, 0.6892983317375183, 0.6921296715736389, 0.8031801581382751, 0.7480284571647644, 0.7035781145095825, 0.6147076487541199, 0.77727 ...

# %%
#exp3

# %%
import tensorflow
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import tensorflow as tf
# Importing Deep Learning Libraries
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from keras import regularizers
from keras.preprocessing import image

#HISTOGRAM CODE
#histogram code
import matplotlib.pyplot as plt
import os

emotions = ["happy", "sadness", "anger", "disgust", "neutral", "fear", "surprise"]

folder_path = "Jaffetrainvalidation/train"
# Counting the number of images per emotion
counts = [len(os.listdir(os.path.join(folder_path, emotion))) for emotion in emotions]

# Plotting the bar chart
colors = ['red', 'yellow', 'black', 'blue', 'orange', 'green', 'pink']
plt.bar(emotions, height=counts, color=colors)
plt.ylabel('Number')
plt.xlabel('Emotions')


#plt.savefig('hostgoarm.png')
#plt.show()


# Data generators
batch_size = 64

# Data augmentation for training set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Normalization for validation set (no augmentation)
datagen_val = ImageDataGenerator(rescale=1./255)



train_ds = datagen_train.flow_from_directory("Jaffetrainvalidation/train",
                                             target_size=(256, 256),
                                             color_mode="rgb",
                                             batch_size=batch_size,
                                             class_mode='categorical',
                                             shuffle=True)

test_ds = datagen_val.flow_from_directory("Jaffetrainvalidation/validation",
                                         target_size=(256, 256),
                                         color_mode="rgb",
                                         batch_size=batch_size,
                                         class_mode='categorical',
                                         shuffle=False)
print('Train and Validation sets have been created.')


from keras.applications.resnet import ResNet152
conv_base = ResNet152(
    weights='imagenet',
    include_top = False,
    input_shape=(256,256,3)
)


conv_base.summary()


model = Sequential()

model.add(conv_base)
model.add(Flatten())
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))
# Second fully connected layer  
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))

model.add(Dense(7, activation='softmax'))

# model.summary()
# Visualize the model.
#plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

conv_base.trainable = False

model.compile(optimizer = Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

print('CNN model has been created you can proceed to train you data with this model.')




# Training the model
epochs = 500

history = model.fit(x=train_ds,
                    epochs=epochs,
                    validation_data=test_ds)

# Print training history
print(history.history)

# Plotting training history
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# Found 168 images belonging to 7 classes.
# Found 45 images belonging to 7 classes.
# Train and Validation sets have been created.
# Model: "resnet152"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 262, 262, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 128, 128, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 128, 128, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 130, 130, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 64, 64, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 64, 64, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 64, 64, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 64, 64, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 64, 64, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 64, 64, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 32, 32, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 32, 32, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#  conv3_block2_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 32, 32, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 32, 32, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 32, 32, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 32, 32, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 32, 32, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block4_out[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_2_conv[0][0]']
#  rmalization)
#
#  conv3_block5_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_2_bn[0][0]']
#  ation)
#
#  conv3_block5_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block5_2_relu[0][0]']
#  D)
#
#  conv3_block5_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block5_3_conv[0][0]']
#  rmalization)
#
#  conv3_block5_add (Add)      (None, 32, 32, 512)          0         ['conv3_block4_out[0][0]',
#                                                                      'conv3_block5_3_bn[0][0]']
#
#  conv3_block5_out (Activati  (None, 32, 32, 512)          0         ['conv3_block5_add[0][0]']
#  on)
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block5_out[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_2_conv[0][0]']
#  rmalization)
#
#  conv3_block6_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_2_bn[0][0]']
#  ation)
#
#  conv3_block6_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block6_2_relu[0][0]']
#  D)
#
#  conv3_block6_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block6_3_conv[0][0]']
#  rmalization)
#
#  conv3_block6_add (Add)      (None, 32, 32, 512)          0         ['conv3_block5_out[0][0]',
#                                                                      'conv3_block6_3_bn[0][0]']
#
#  conv3_block6_out (Activati  (None, 32, 32, 512)          0         ['conv3_block6_add[0][0]']
#  on)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block6_out[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_2_conv[0][0]']
#  rmalization)
#
#  conv3_block7_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_2_bn[0][0]']
#  ation)
#
#  conv3_block7_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block7_2_relu[0][0]']
#  D)
#
#  conv3_block7_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block7_3_conv[0][0]']
#  rmalization)
#
#  conv3_block7_add (Add)      (None, 32, 32, 512)          0         ['conv3_block6_out[0][0]',
#                                                                      'conv3_block7_3_bn[0][0]']
#
#  conv3_block7_out (Activati  (None, 32, 32, 512)          0         ['conv3_block7_add[0][0]']
#  on)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block7_out[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_2_conv[0][0]']
#  rmalization)
#
#  conv3_block8_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_2_bn[0][0]']
#  ation)
#
#  conv3_block8_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block8_2_relu[0][0]']
#  D)
#
#  conv3_block8_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block8_3_conv[0][0]']
#  rmalization)
#
#  conv3_block8_add (Add)      (None, 32, 32, 512)          0         ['conv3_block7_out[0][0]',
#                                                                      'conv3_block8_3_bn[0][0]']
#
#  conv3_block8_out (Activati  (None, 32, 32, 512)          0         ['conv3_block8_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 256)          131328    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 16, 16, 1024)         525312    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#  conv4_block2_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
# ...
# Epoch 418/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.5546 - accuracy: 0.8036 - val_loss: 2.5151 - val_accuracy: 0.5556
# Epoch 419/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4772 - accuracy: 0.8155 - val_loss: 2.3066 - val_accuracy: 0.5556
# Epoch 420/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4136 - accuracy: 0.8274 - val_loss: 1.8662 - val_accuracy: 0.6000
# Epoch 421/500
# 3/3 [==============================] - 2s 640ms/step - loss: 0.5092 - accuracy: 0.8214 - val_loss: 1.5337 - val_accuracy: 0.6444
# Epoch 422/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.4977 - accuracy: 0.8274 - val_loss: 1.8621 - val_accuracy: 0.5778
# Epoch 423/500
# 3/3 [==============================] - 2s 495ms/step - loss: 0.4830 - accuracy: 0.8155 - val_loss: 2.1965 - val_accuracy: 0.5111
# Epoch 424/500
# 3/3 [==============================] - 2s 502ms/step - loss: 0.5040 - accuracy: 0.8274 - val_loss: 2.2431 - val_accuracy: 0.4222
# Epoch 425/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.5195 - accuracy: 0.8036 - val_loss: 1.6055 - val_accuracy: 0.5556
# Epoch 426/500
# 3/3 [==============================] - 2s 501ms/step - loss: 0.5318 - accuracy: 0.7917 - val_loss: 1.3830 - val_accuracy: 0.6444
# Epoch 427/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4405 - accuracy: 0.8333 - val_loss: 2.2232 - val_accuracy: 0.5111
# Epoch 428/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.5385 - accuracy: 0.7798 - val_loss: 3.8807 - val_accuracy: 0.3111
# Epoch 429/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4757 - accuracy: 0.8393 - val_loss: 3.6813 - val_accuracy: 0.3778
# Epoch 430/500
# 3/3 [==============================] - 2s 668ms/step - loss: 0.5149 - accuracy: 0.8095 - val_loss: 2.8592 - val_accuracy: 0.4000
# Epoch 431/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5087 - accuracy: 0.7857 - val_loss: 2.5718 - val_accuracy: 0.4889
# Epoch 432/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.4033 - accuracy: 0.8631 - val_loss: 2.6816 - val_accuracy: 0.5333
# Epoch 433/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4807 - accuracy: 0.8214 - val_loss: 2.6388 - val_accuracy: 0.5111
# Epoch 434/500
# 3/3 [==============================] - 2s 676ms/step - loss: 0.4825 - accuracy: 0.8274 - val_loss: 3.0825 - val_accuracy: 0.4000
# Epoch 435/500
# 3/3 [==============================] - 2s 495ms/step - loss: 0.3789 - accuracy: 0.8690 - val_loss: 3.1493 - val_accuracy: 0.4444
# Epoch 436/500
# 3/3 [==============================] - 2s 672ms/step - loss: 0.4636 - accuracy: 0.8274 - val_loss: 2.9588 - val_accuracy: 0.4667
# Epoch 437/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.4912 - accuracy: 0.8036 - val_loss: 2.9097 - val_accuracy: 0.5333
# Epoch 438/500
# 3/3 [==============================] - 2s 662ms/step - loss: 0.5610 - accuracy: 0.7917 - val_loss: 2.6710 - val_accuracy: 0.5556
# Epoch 439/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4349 - accuracy: 0.8452 - val_loss: 2.3298 - val_accuracy: 0.5333
# Epoch 440/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.4191 - accuracy: 0.8214 - val_loss: 1.8107 - val_accuracy: 0.6000
# Epoch 441/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.5043 - accuracy: 0.8274 - val_loss: 1.3344 - val_accuracy: 0.6889
# Epoch 442/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4756 - accuracy: 0.8214 - val_loss: 1.3179 - val_accuracy: 0.7111
# Epoch 443/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4670 - accuracy: 0.7857 - val_loss: 1.5612 - val_accuracy: 0.7111
# Epoch 444/500
# 3/3 [==============================] - 2s 500ms/step - loss: 0.6292 - accuracy: 0.8095 - val_loss: 2.0395 - val_accuracy: 0.5778
# Epoch 445/500
# 3/3 [==============================] - 2s 672ms/step - loss: 0.4675 - accuracy: 0.8512 - val_loss: 2.8995 - val_accuracy: 0.4889
# Epoch 446/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.4585 - accuracy: 0.8095 - val_loss: 3.4072 - val_accuracy: 0.4444
# Epoch 447/500
# 3/3 [==============================] - 2s 499ms/step - loss: 0.5285 - accuracy: 0.8274 - val_loss: 3.1300 - val_accuracy: 0.4667
# Epoch 448/500
# 3/3 [==============================] - 2s 672ms/step - loss: 0.5586 - accuracy: 0.7917 - val_loss: 2.4246 - val_accuracy: 0.5778
# Epoch 449/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5845 - accuracy: 0.8095 - val_loss: 2.3864 - val_accuracy: 0.5333
# Epoch 450/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5082 - accuracy: 0.8155 - val_loss: 2.2664 - val_accuracy: 0.5111
# Epoch 451/500
# 3/3 [==============================] - 2s 657ms/step - loss: 0.3819 - accuracy: 0.8869 - val_loss: 2.3932 - val_accuracy: 0.5111
# Epoch 452/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.4801 - accuracy: 0.8095 - val_loss: 2.4304 - val_accuracy: 0.4222
# Epoch 453/500
# 3/3 [==============================] - 2s 499ms/step - loss: 0.4863 - accuracy: 0.8155 - val_loss: 2.7465 - val_accuracy: 0.3778
# Epoch 454/500
# 3/3 [==============================] - 2s 669ms/step - loss: 0.3368 - accuracy: 0.8810 - val_loss: 2.7404 - val_accuracy: 0.3778
# Epoch 455/500
# 3/3 [==============================] - 2s 686ms/step - loss: 0.4160 - accuracy: 0.8274 - val_loss: 3.1713 - val_accuracy: 0.4000
# Epoch 456/500
# 3/3 [==============================] - 2s 667ms/step - loss: 0.4039 - accuracy: 0.8333 - val_loss: 3.6777 - val_accuracy: 0.3556
# Epoch 457/500
# 3/3 [==============================] - 2s 676ms/step - loss: 0.3299 - accuracy: 0.8869 - val_loss: 4.0138 - val_accuracy: 0.3333
# Epoch 458/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.5204 - accuracy: 0.8036 - val_loss: 3.7620 - val_accuracy: 0.3333
# Epoch 459/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4572 - accuracy: 0.8452 - val_loss: 2.9564 - val_accuracy: 0.3556
# Epoch 460/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.5162 - accuracy: 0.8155 - val_loss: 2.2828 - val_accuracy: 0.5111
# Epoch 461/500
# 3/3 [==============================] - 2s 488ms/step - loss: 0.4315 - accuracy: 0.8333 - val_loss: 2.1884 - val_accuracy: 0.5333
# Epoch 462/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5201 - accuracy: 0.8095 - val_loss: 2.6128 - val_accuracy: 0.3778
# Epoch 463/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5272 - accuracy: 0.8333 - val_loss: 3.2954 - val_accuracy: 0.3556
# Epoch 464/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5778 - accuracy: 0.8155 - val_loss: 5.3010 - val_accuracy: 0.2889
# Epoch 465/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.4568 - accuracy: 0.8333 - val_loss: 5.3998 - val_accuracy: 0.2889
# Epoch 466/500
# 3/3 [==============================] - 2s 680ms/step - loss: 0.4486 - accuracy: 0.8333 - val_loss: 4.7861 - val_accuracy: 0.3333
# Epoch 467/500
# 3/3 [==============================] - 2s 661ms/step - loss: 0.5307 - accuracy: 0.7619 - val_loss: 3.6832 - val_accuracy: 0.3111
# Epoch 468/500
# 3/3 [==============================] - 2s 498ms/step - loss: 0.4217 - accuracy: 0.8155 - val_loss: 3.5886 - val_accuracy: 0.2889
# Epoch 469/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5572 - accuracy: 0.7917 - val_loss: 4.4303 - val_accuracy: 0.2889
# Epoch 470/500
# 3/3 [==============================] - 2s 675ms/step - loss: 0.4452 - accuracy: 0.8512 - val_loss: 4.1668 - val_accuracy: 0.2889
# Epoch 471/500
# 3/3 [==============================] - 2s 501ms/step - loss: 0.4501 - accuracy: 0.8274 - val_loss: 3.8846 - val_accuracy: 0.3556
# Epoch 472/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.5658 - accuracy: 0.8095 - val_loss: 3.6673 - val_accuracy: 0.4000
# Epoch 473/500
# 3/3 [==============================] - 2s 502ms/step - loss: 0.6003 - accuracy: 0.7917 - val_loss: 3.4435 - val_accuracy: 0.4444
# Epoch 474/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4603 - accuracy: 0.8333 - val_loss: 3.2363 - val_accuracy: 0.4222
# Epoch 475/500
# 3/3 [==============================] - 2s 663ms/step - loss: 0.5951 - accuracy: 0.7619 - val_loss: 3.1828 - val_accuracy: 0.4222
# Epoch 476/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.4091 - accuracy: 0.8571 - val_loss: 3.0465 - val_accuracy: 0.4000
# Epoch 477/500
# 3/3 [==============================] - 2s 498ms/step - loss: 0.4589 - accuracy: 0.8333 - val_loss: 2.7213 - val_accuracy: 0.4667
# Epoch 478/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.3611 - accuracy: 0.8631 - val_loss: 2.4718 - val_accuracy: 0.4667
# Epoch 479/500
# 3/3 [==============================] - 2s 512ms/step - loss: 0.5492 - accuracy: 0.7917 - val_loss: 2.4272 - val_accuracy: 0.4444
# Epoch 480/500
# 3/3 [==============================] - 2s 504ms/step - loss: 0.4094 - accuracy: 0.8393 - val_loss: 2.3608 - val_accuracy: 0.4667
# Epoch 481/500
# 3/3 [==============================] - 2s 670ms/step - loss: 0.3961 - accuracy: 0.8452 - val_loss: 1.9700 - val_accuracy: 0.5333
# Epoch 482/500
# 3/3 [==============================] - 2s 675ms/step - loss: 0.4228 - accuracy: 0.8452 - val_loss: 1.5248 - val_accuracy: 0.6667
# Epoch 483/500
# 3/3 [==============================] - 2s 666ms/step - loss: 0.4099 - accuracy: 0.8393 - val_loss: 1.5312 - val_accuracy: 0.6444
# Epoch 484/500
# 3/3 [==============================] - 2s 665ms/step - loss: 0.4923 - accuracy: 0.8036 - val_loss: 1.5208 - val_accuracy: 0.7111
# Epoch 485/500
# 3/3 [==============================] - 2s 506ms/step - loss: 0.5256 - accuracy: 0.7917 - val_loss: 1.9052 - val_accuracy: 0.6000
# Epoch 486/500
# 3/3 [==============================] - 2s 495ms/step - loss: 0.4235 - accuracy: 0.8631 - val_loss: 2.2786 - val_accuracy: 0.4444
# Epoch 487/500
# 3/3 [==============================] - 2s 500ms/step - loss: 0.4621 - accuracy: 0.7976 - val_loss: 2.7970 - val_accuracy: 0.4000
# Epoch 488/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.4314 - accuracy: 0.8631 - val_loss: 2.9259 - val_accuracy: 0.4444
# Epoch 489/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4457 - accuracy: 0.8333 - val_loss: 2.6905 - val_accuracy: 0.5111
# Epoch 490/500
# 3/3 [==============================] - 2s 666ms/step - loss: 0.5331 - accuracy: 0.7917 - val_loss: 2.4527 - val_accuracy: 0.5556
# Epoch 491/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5269 - accuracy: 0.8036 - val_loss: 3.0015 - val_accuracy: 0.5333
# Epoch 492/500
# 3/3 [==============================] - 2s 499ms/step - loss: 0.4537 - accuracy: 0.8214 - val_loss: 2.9550 - val_accuracy: 0.5556
# Epoch 493/500
# 3/3 [==============================] - 2s 498ms/step - loss: 0.3866 - accuracy: 0.8631 - val_loss: 2.6146 - val_accuracy: 0.5111
# Epoch 494/500
# 3/3 [==============================] - 2s 498ms/step - loss: 0.4876 - accuracy: 0.8036 - val_loss: 2.5231 - val_accuracy: 0.4444
# Epoch 495/500
# 3/3 [==============================] - 2s 675ms/step - loss: 0.4098 - accuracy: 0.8690 - val_loss: 1.9996 - val_accuracy: 0.5111
# Epoch 496/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.5203 - accuracy: 0.7976 - val_loss: 1.7836 - val_accuracy: 0.5556
# Epoch 497/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4470 - accuracy: 0.8274 - val_loss: 2.1928 - val_accuracy: 0.5111
# Epoch 498/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5729 - accuracy: 0.8333 - val_loss: 2.5556 - val_accuracy: 0.4667
# Epoch 499/500
# 3/3 [==============================] - 2s 504ms/step - loss: 0.4253 - accuracy: 0.8214 - val_loss: 2.7848 - val_accuracy: 0.4667
# Epoch 500/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4667 - accuracy: 0.8333 - val_loss: 3.3824 - val_accuracy: 0.4444
# {'loss': [3.181392192840576, 2.5661869049072266, 2.576298952102661, 2.39458966255188, 2.300920009613037, 2.153508186340332, 2.127286672592163, 2.2705540657043457, 2.1764276027679443, 2.0925161838531494, 2.087489604949951, 2.022643566131592, 1.975876808166504, 2.0946385860443115, 1.9437960386276245, 1.943580985069275, 1.9307185411453247, 1.9052934646606445, 1.990930438041687, 1.8188691139221191, 1.8621782064437866, 1.7390296459197998, 1.7022250890731812, 1.7719767093658447, 1.693114995956421, 1.809422492980957, 1.8450771570205688, 1.6573961973190308, 1.7214834690093994, 1.6620417833328247, 1.576574444770813, 1.6376137733459473, 1.7294442653656006, 1.6100636720657349, 1.5597023963928223, 1.6921993494033813, 1.7976375818252563, 1.7065398693084717, 1.5539515018463135, 1.4775505065917969, 1.4616777896881104, 1.4446895122528076, 1.536177158355713, 1.615186095237732, 1.465234398841858, 1.337719202041626, 1.5368013381958008, 1.4986737966537476, 1.3466912508010864, 1.5857487916946411, 1.51308274269104, 1.4579638242721558, 1.4655485153198242, 1.3243414163589478, 1.336292028427124, 1.666608214378357, 1.4028698205947876, 1.4278360605239868, 1.413686990737915, 1.2851638793945312, 1.4506733417510986, 1.4383516311645508, 1.4196627140045166, 1.2383979558944702, 1.4166381359100342, 1.1721558570861816, 1.3126084804534912, 1.2406084537506104, 1.2001436948776245, 1.1767467260360718, 1.265941858291626, 1.241437554359436, 1.2262017726898193, 1.2579641342163086, 1.150708556175232, 1.2845945358276367, 1.2149016857147217, 1.3688879013061523, 1.2105833292007446, 1.1562371253967285, 1.1980458498001099, 1.292049765586853, 1.1557950973510742, 1.1557670831680298, 1.1793428659439087, 1.2047127485275269, 1.1570230722427368, 1.028779149055481, 1.1819013357162476, 0.9904681444168091, 1.1136080026626587, 1.1621884107589722, 1.0380955934524536, 0.9511042237281799, 1.1038411855697632, 1.0998587608337402, 1.0937423706054688, 0.9430058598518372, 0.9958321452140808, 1.100497841835022, 1.1264801025390625, 1.1601873636245728, 1.0253962278366089, 0.9566251635551453, 0.8268216252326965, 1.0816582441329956, 0.9352484345436096, 0.970848798751831, 0.9375078082084656, 1.0905793905258179, 0.9395469427108765, 0.8623249530792236, 1.0446826219558716, 1.1237709522247314, 1.0222641229629517, 1.01139497756958, 0.8994066119194031, 0.9644432067871094, 0.9199966192245483, 1.038710594177246, 1.0526844263076782, 1.0641435384750366, 0.901854395866394, 0.9178499579429626, 0.9363692998886108, 0.8090971112251282, 0.8418993353843689, 0.8251243829727173, 0.8953032493591309, 0.9885315895080566, 0.7752076983451843, 0.8857376575469971, 0.7996994853019714, 0.8778256773948669, 0.9241487383842468, 0.9721681475639343, 0.8609034419059753, 0.9268782734870911, 0.7974650263786316, 0.8471974730491638, 0.8040328025817871, 0.9009411931037903, 0.9839619398117065, 0.821404218673706, 0.9664766192436218, 0.9883860349655151, 0.7897064685821533, 0.9957981109619141, 0.8313624262809753, 0.941260576248169, 0.7642717957496643, 0.9118294715881348, 0.8890560865402222, 0.8191953301429749, 0.8406515717506409, 0.9161278009414673, 0.8834556341171265, 0.9321168065071106, 0.9610599279403687, 0.7663267254829407, 0.7937453985214233, 0.8106458783149719, 0.8948262333869934, 0.8273112177848816, 0.7556265592575073, 0.8201127648353577, 0.6824039816856384, 0.8437520265579224, 0.801880955696106, 0.8364960551261902, 0.742132842540741, 0.8079988360404968, 0.8819091320037842, 0.7606557011604309, 0.7825163006782532, 0.773501992225647, 0.7628539204597473, 0.8084638714790344, 0.7070086002349854, 0.8655064702033997, 0.7892995476722717, 0.7250625491142273, 0.7651860117912292, 0.7015088796615601, 0.5635563731193542, 0.9045401811599731, 0.7497057914733887, 0.7974360585212708, 0.766086220741272, 0.6393155455589294, 0.8173735737800598, 0.6925339698791504, 0.6692929267883301, 0.6575400829315186, 0.715337336063385, 0.7050530314445496, 0.7386655211448669, 0.8976934552192688, 0.7953726649284363, 0.7661292552947998, 0.8375470042228699, 0.5423337817 ...

# %%
#exp4

# %%
import tensorflow
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import tensorflow as tf
# Importing Deep Learning Libraries
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from keras import regularizers
from keras.preprocessing import image

#HISTOGRAM CODE
#histogram code
import matplotlib.pyplot as plt
import os

emotions = ["happy", "sadness", "anger", "disgust", "neutral", "fear", "surprise"]

folder_path = "Jaffetrainvalidation/train"
# Counting the number of images per emotion
counts = [len(os.listdir(os.path.join(folder_path, emotion))) for emotion in emotions]

# Plotting the bar chart
colors = ['red', 'yellow', 'black', 'blue', 'orange', 'green', 'pink']
plt.bar(emotions, height=counts, color=colors)
plt.ylabel('Number')
plt.xlabel('Emotions')


#plt.savefig('hostgoarm.png')
#plt.show()


# Data generators
batch_size = 64

# Data augmentation for training set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Normalization for validation set (no augmentation)
datagen_val = ImageDataGenerator(rescale=1./255)



train_ds = datagen_train.flow_from_directory("Jaffetrainvalidation/train",
                                             target_size=(256, 256),
                                             color_mode="rgb",
                                             batch_size=batch_size,
                                             class_mode='categorical',
                                             shuffle=True)

test_ds = datagen_val.flow_from_directory("Jaffetrainvalidation/validation",
                                         target_size=(256, 256),
                                         color_mode="rgb",
                                         batch_size=batch_size,
                                         class_mode='categorical',
                                         shuffle=False)
print('Train and Validation sets have been created.')


from keras.applications.resnet import ResNet152
conv_base = ResNet152(
    weights='imagenet',
    include_top = False,
    input_shape=(256,256,3)
)


conv_base.summary()


model = Sequential()

model.add(conv_base)
model.add(Flatten())
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))
# Second fully connected layer  
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))

model.add(Dense(7, activation='softmax'))

# model.summary()
# Visualize the model.
#plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

conv_base.trainable = False

model.compile(optimizer = Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

print('CNN model has been created you can proceed to train you data with this model.')




# Training the model
epochs = 500

history = model.fit(x=train_ds,
                    epochs=epochs,
                    validation_data=test_ds)

# Print training history
print(history.history)

# Plotting training history
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# Found 168 images belonging to 7 classes.
# Found 45 images belonging to 7 classes.
# Train and Validation sets have been created.
# Model: "resnet152"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 262, 262, 3)          0         ['input_3[0][0]']
#
#  conv1_conv (Conv2D)         (None, 128, 128, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 128, 128, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 130, 130, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 64, 64, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 64, 64, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 64, 64, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 64, 64, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 64, 64, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 64, 64, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 32, 32, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 32, 32, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#  conv3_block2_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 32, 32, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 32, 32, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 32, 32, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 32, 32, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 32, 32, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block4_out[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_2_conv[0][0]']
#  rmalization)
#
#  conv3_block5_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_2_bn[0][0]']
#  ation)
#
#  conv3_block5_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block5_2_relu[0][0]']
#  D)
#
#  conv3_block5_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block5_3_conv[0][0]']
#  rmalization)
#
#  conv3_block5_add (Add)      (None, 32, 32, 512)          0         ['conv3_block4_out[0][0]',
#                                                                      'conv3_block5_3_bn[0][0]']
#
#  conv3_block5_out (Activati  (None, 32, 32, 512)          0         ['conv3_block5_add[0][0]']
#  on)
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block5_out[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_2_conv[0][0]']
#  rmalization)
#
#  conv3_block6_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_2_bn[0][0]']
#  ation)
#
#  conv3_block6_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block6_2_relu[0][0]']
#  D)
#
#  conv3_block6_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block6_3_conv[0][0]']
#  rmalization)
#
#  conv3_block6_add (Add)      (None, 32, 32, 512)          0         ['conv3_block5_out[0][0]',
#                                                                      'conv3_block6_3_bn[0][0]']
#
#  conv3_block6_out (Activati  (None, 32, 32, 512)          0         ['conv3_block6_add[0][0]']
#  on)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block6_out[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_2_conv[0][0]']
#  rmalization)
#
#  conv3_block7_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_2_bn[0][0]']
#  ation)
#
#  conv3_block7_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block7_2_relu[0][0]']
#  D)
#
#  conv3_block7_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block7_3_conv[0][0]']
#  rmalization)
#
#  conv3_block7_add (Add)      (None, 32, 32, 512)          0         ['conv3_block6_out[0][0]',
#                                                                      'conv3_block7_3_bn[0][0]']
#
#  conv3_block7_out (Activati  (None, 32, 32, 512)          0         ['conv3_block7_add[0][0]']
#  on)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block7_out[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_2_conv[0][0]']
#  rmalization)
#
#  conv3_block8_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_2_bn[0][0]']
#  ation)
#
#  conv3_block8_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block8_2_relu[0][0]']
#  D)
#
#  conv3_block8_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block8_3_conv[0][0]']
#  rmalization)
#
#  conv3_block8_add (Add)      (None, 32, 32, 512)          0         ['conv3_block7_out[0][0]',
#                                                                      'conv3_block8_3_bn[0][0]']
#
#  conv3_block8_out (Activati  (None, 32, 32, 512)          0         ['conv3_block8_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 256)          131328    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 16, 16, 1024)         525312    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#  conv4_block2_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
# ...
# Epoch 418/500
# 3/3 [==============================] - 2s 495ms/step - loss: 0.5662 - accuracy: 0.7857 - val_loss: 3.8874 - val_accuracy: 0.3111
# Epoch 419/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4445 - accuracy: 0.8512 - val_loss: 5.2699 - val_accuracy: 0.2222
# Epoch 420/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.5518 - accuracy: 0.8095 - val_loss: 5.6209 - val_accuracy: 0.2444
# Epoch 421/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5632 - accuracy: 0.7619 - val_loss: 6.3114 - val_accuracy: 0.2222
# Epoch 422/500
# 3/3 [==============================] - 2s 639ms/step - loss: 0.4910 - accuracy: 0.8393 - val_loss: 4.3311 - val_accuracy: 0.2444
# Epoch 423/500
# 3/3 [==============================] - 2s 488ms/step - loss: 0.6035 - accuracy: 0.7798 - val_loss: 3.5506 - val_accuracy: 0.3333
# Epoch 424/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.4470 - accuracy: 0.8452 - val_loss: 3.6635 - val_accuracy: 0.3111
# Epoch 425/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.5689 - accuracy: 0.7798 - val_loss: 3.4018 - val_accuracy: 0.3556
# Epoch 426/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.4638 - accuracy: 0.8155 - val_loss: 2.6944 - val_accuracy: 0.4444
# Epoch 427/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.5415 - accuracy: 0.7976 - val_loss: 2.6957 - val_accuracy: 0.4444
# Epoch 428/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.5171 - accuracy: 0.8036 - val_loss: 2.9037 - val_accuracy: 0.4667
# Epoch 429/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.4850 - accuracy: 0.8214 - val_loss: 3.0633 - val_accuracy: 0.4444
# Epoch 430/500
# 3/3 [==============================] - 2s 643ms/step - loss: 0.4898 - accuracy: 0.8452 - val_loss: 3.1381 - val_accuracy: 0.5111
# Epoch 431/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.3770 - accuracy: 0.8274 - val_loss: 3.0502 - val_accuracy: 0.5111
# Epoch 432/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4705 - accuracy: 0.8333 - val_loss: 2.6261 - val_accuracy: 0.5556
# Epoch 433/500
# 3/3 [==============================] - 2s 484ms/step - loss: 0.6003 - accuracy: 0.7857 - val_loss: 2.6130 - val_accuracy: 0.5778
# Epoch 434/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.4716 - accuracy: 0.8155 - val_loss: 2.3057 - val_accuracy: 0.5778
# Epoch 435/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5621 - accuracy: 0.7917 - val_loss: 2.0549 - val_accuracy: 0.5556
# Epoch 436/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4918 - accuracy: 0.8512 - val_loss: 1.1527 - val_accuracy: 0.7111
# Epoch 437/500
# 3/3 [==============================] - 2s 635ms/step - loss: 0.4424 - accuracy: 0.8690 - val_loss: 0.9750 - val_accuracy: 0.7333
# Epoch 438/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.3922 - accuracy: 0.8690 - val_loss: 0.9491 - val_accuracy: 0.6667
# Epoch 439/500
# 3/3 [==============================] - 2s 643ms/step - loss: 0.5919 - accuracy: 0.7857 - val_loss: 0.9005 - val_accuracy: 0.7333
# Epoch 440/500
# 3/3 [==============================] - 2s 647ms/step - loss: 0.4566 - accuracy: 0.8571 - val_loss: 0.9332 - val_accuracy: 0.7556
# Epoch 441/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4966 - accuracy: 0.8155 - val_loss: 0.9022 - val_accuracy: 0.7778
# Epoch 442/500
# 3/3 [==============================] - 2s 497ms/step - loss: 0.5327 - accuracy: 0.7798 - val_loss: 1.0002 - val_accuracy: 0.6444
# Epoch 443/500
# 3/3 [==============================] - 2s 638ms/step - loss: 0.5621 - accuracy: 0.7976 - val_loss: 1.1001 - val_accuracy: 0.6444
# Epoch 444/500
# 3/3 [==============================] - 2s 650ms/step - loss: 0.5257 - accuracy: 0.8155 - val_loss: 1.3797 - val_accuracy: 0.6222
# Epoch 445/500
# 3/3 [==============================] - 2s 501ms/step - loss: 0.4914 - accuracy: 0.8452 - val_loss: 1.7880 - val_accuracy: 0.6222
# Epoch 446/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4226 - accuracy: 0.8274 - val_loss: 2.1182 - val_accuracy: 0.6222
# Epoch 447/500
# 3/3 [==============================] - 2s 639ms/step - loss: 0.4678 - accuracy: 0.8274 - val_loss: 3.1781 - val_accuracy: 0.4889
# Epoch 448/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.4951 - accuracy: 0.7857 - val_loss: 4.2347 - val_accuracy: 0.3556
# Epoch 449/500
# 3/3 [==============================] - 2s 638ms/step - loss: 0.5005 - accuracy: 0.8095 - val_loss: 4.5030 - val_accuracy: 0.3333
# Epoch 450/500
# 3/3 [==============================] - 2s 634ms/step - loss: 0.4496 - accuracy: 0.8393 - val_loss: 3.9654 - val_accuracy: 0.3778
# Epoch 451/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5311 - accuracy: 0.7976 - val_loss: 2.5800 - val_accuracy: 0.4889
# Epoch 452/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5522 - accuracy: 0.7857 - val_loss: 2.0817 - val_accuracy: 0.5778
# Epoch 453/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.4345 - accuracy: 0.8155 - val_loss: 1.7165 - val_accuracy: 0.6667
# Epoch 454/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.4073 - accuracy: 0.8512 - val_loss: 1.6524 - val_accuracy: 0.6667
# Epoch 455/500
# 3/3 [==============================] - 2s 501ms/step - loss: 0.4823 - accuracy: 0.8571 - val_loss: 1.3381 - val_accuracy: 0.6889
# Epoch 456/500
# 3/3 [==============================] - 2s 637ms/step - loss: 0.5104 - accuracy: 0.7917 - val_loss: 1.1308 - val_accuracy: 0.7778
# Epoch 457/500
# 3/3 [==============================] - 2s 637ms/step - loss: 0.4353 - accuracy: 0.8214 - val_loss: 1.3152 - val_accuracy: 0.6889
# Epoch 458/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5020 - accuracy: 0.8155 - val_loss: 1.2683 - val_accuracy: 0.7111
# Epoch 459/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.3136 - accuracy: 0.8750 - val_loss: 1.0367 - val_accuracy: 0.7778
# Epoch 460/500
# 3/3 [==============================] - 2s 635ms/step - loss: 0.4573 - accuracy: 0.8155 - val_loss: 1.3047 - val_accuracy: 0.6889
# Epoch 461/500
# 3/3 [==============================] - 2s 500ms/step - loss: 0.4695 - accuracy: 0.8333 - val_loss: 2.0541 - val_accuracy: 0.5778
# Epoch 462/500
# 3/3 [==============================] - 2s 635ms/step - loss: 0.5288 - accuracy: 0.7738 - val_loss: 2.5953 - val_accuracy: 0.5333
# Epoch 463/500
# 3/3 [==============================] - 2s 640ms/step - loss: 0.4844 - accuracy: 0.8393 - val_loss: 2.8224 - val_accuracy: 0.5111
# Epoch 464/500
# 3/3 [==============================] - 2s 642ms/step - loss: 0.4051 - accuracy: 0.8690 - val_loss: 2.9242 - val_accuracy: 0.4889
# Epoch 465/500
# 3/3 [==============================] - 2s 642ms/step - loss: 0.5919 - accuracy: 0.7917 - val_loss: 2.8442 - val_accuracy: 0.5778
# Epoch 466/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5633 - accuracy: 0.8095 - val_loss: 2.8920 - val_accuracy: 0.5111
# Epoch 467/500
# 3/3 [==============================] - 2s 634ms/step - loss: 0.5025 - accuracy: 0.8393 - val_loss: 2.6504 - val_accuracy: 0.5556
# Epoch 468/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.4283 - accuracy: 0.8452 - val_loss: 2.5139 - val_accuracy: 0.5333
# Epoch 469/500
# 3/3 [==============================] - 2s 633ms/step - loss: 0.5102 - accuracy: 0.8095 - val_loss: 2.7967 - val_accuracy: 0.6000
# Epoch 470/500
# 3/3 [==============================] - 2s 643ms/step - loss: 0.5027 - accuracy: 0.8095 - val_loss: 2.9710 - val_accuracy: 0.5778
# Epoch 471/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.6316 - accuracy: 0.7619 - val_loss: 3.3733 - val_accuracy: 0.5556
# Epoch 472/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.4793 - accuracy: 0.8452 - val_loss: 3.3576 - val_accuracy: 0.5556
# Epoch 473/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.5095 - accuracy: 0.8214 - val_loss: 3.9148 - val_accuracy: 0.4222
# Epoch 474/500
# 3/3 [==============================] - 2s 633ms/step - loss: 0.5660 - accuracy: 0.8274 - val_loss: 3.4168 - val_accuracy: 0.4444
# Epoch 475/500
# 3/3 [==============================] - 2s 488ms/step - loss: 0.4737 - accuracy: 0.8333 - val_loss: 2.1244 - val_accuracy: 0.5556
# Epoch 476/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.4340 - accuracy: 0.8452 - val_loss: 1.6323 - val_accuracy: 0.5333
# Epoch 477/500
# 3/3 [==============================] - 2s 500ms/step - loss: 0.5085 - accuracy: 0.7917 - val_loss: 1.8085 - val_accuracy: 0.5556
# Epoch 478/500
# 3/3 [==============================] - 2s 492ms/step - loss: 0.4435 - accuracy: 0.8512 - val_loss: 1.8971 - val_accuracy: 0.4889
# Epoch 479/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.5421 - accuracy: 0.7976 - val_loss: 1.9639 - val_accuracy: 0.5111
# Epoch 480/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5076 - accuracy: 0.7976 - val_loss: 1.4704 - val_accuracy: 0.6000
# Epoch 481/500
# 3/3 [==============================] - 2s 502ms/step - loss: 0.4284 - accuracy: 0.8512 - val_loss: 1.0480 - val_accuracy: 0.6889
# Epoch 482/500
# 3/3 [==============================] - 2s 499ms/step - loss: 0.4570 - accuracy: 0.8393 - val_loss: 0.8936 - val_accuracy: 0.7333
# Epoch 483/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4211 - accuracy: 0.8571 - val_loss: 0.9217 - val_accuracy: 0.7333
# Epoch 484/500
# 3/3 [==============================] - 2s 489ms/step - loss: 0.4774 - accuracy: 0.8274 - val_loss: 1.0138 - val_accuracy: 0.6667
# Epoch 485/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.3778 - accuracy: 0.8512 - val_loss: 1.8554 - val_accuracy: 0.4444
# Epoch 486/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5330 - accuracy: 0.8036 - val_loss: 3.5007 - val_accuracy: 0.3778
# Epoch 487/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5653 - accuracy: 0.7560 - val_loss: 4.5567 - val_accuracy: 0.3333
# Epoch 488/500
# 3/3 [==============================] - 2s 485ms/step - loss: 0.4536 - accuracy: 0.8452 - val_loss: 6.0118 - val_accuracy: 0.2667
# Epoch 489/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5032 - accuracy: 0.8333 - val_loss: 7.8306 - val_accuracy: 0.2000
# Epoch 490/500
# 3/3 [==============================] - 2s 488ms/step - loss: 0.4323 - accuracy: 0.8274 - val_loss: 9.3536 - val_accuracy: 0.1556
# Epoch 491/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.5041 - accuracy: 0.8571 - val_loss: 8.8133 - val_accuracy: 0.1333
# Epoch 492/500
# 3/3 [==============================] - 2s 634ms/step - loss: 0.5302 - accuracy: 0.7798 - val_loss: 6.8964 - val_accuracy: 0.2222
# Epoch 493/500
# 3/3 [==============================] - 2s 503ms/step - loss: 0.4709 - accuracy: 0.8452 - val_loss: 4.2797 - val_accuracy: 0.3333
# Epoch 494/500
# 3/3 [==============================] - 2s 486ms/step - loss: 0.6146 - accuracy: 0.7857 - val_loss: 3.3373 - val_accuracy: 0.4000
# Epoch 495/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.5575 - accuracy: 0.8333 - val_loss: 2.2950 - val_accuracy: 0.5333
# Epoch 496/500
# 3/3 [==============================] - 2s 636ms/step - loss: 0.3876 - accuracy: 0.8393 - val_loss: 1.9164 - val_accuracy: 0.5333
# Epoch 497/500
# 3/3 [==============================] - 2s 632ms/step - loss: 0.5100 - accuracy: 0.8274 - val_loss: 2.1866 - val_accuracy: 0.4667
# Epoch 498/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4214 - accuracy: 0.8333 - val_loss: 2.8782 - val_accuracy: 0.4444
# Epoch 499/500
# 3/3 [==============================] - 2s 491ms/step - loss: 0.4867 - accuracy: 0.8036 - val_loss: 3.5047 - val_accuracy: 0.3778
# Epoch 500/500
# 3/3 [==============================] - 2s 487ms/step - loss: 0.4428 - accuracy: 0.8095 - val_loss: 2.9469 - val_accuracy: 0.4889
# {'loss': [3.0701045989990234, 2.618346691131592, 2.5374667644500732, 2.5212206840515137, 2.3550970554351807, 2.370483875274658, 2.2081973552703857, 2.3246326446533203, 2.29132342338562, 2.2294983863830566, 2.2072269916534424, 2.239560127258301, 2.0442771911621094, 2.1199421882629395, 2.022949695587158, 1.9492101669311523, 2.0250470638275146, 1.9645620584487915, 1.9536597728729248, 1.8389289379119873, 1.752929925918579, 1.8625608682632446, 1.8126200437545776, 1.7399680614471436, 1.8194901943206787, 1.7724242210388184, 1.7500097751617432, 1.8134217262268066, 1.9812428951263428, 1.7515952587127686, 1.604656457901001, 1.6207871437072754, 1.6276772022247314, 1.591394305229187, 1.5324583053588867, 1.6664705276489258, 1.5843477249145508, 1.5104937553405762, 1.5279541015625, 1.5056514739990234, 1.482820749282837, 1.411391258239746, 1.492409348487854, 1.4930260181427002, 1.4292585849761963, 1.4787734746932983, 1.3853554725646973, 1.3837182521820068, 1.352910041809082, 1.5882527828216553, 1.332044005393982, 1.3960862159729004, 1.5956326723098755, 1.5416241884231567, 1.4017229080200195, 1.4614460468292236, 1.3004839420318604, 1.232523798942566, 1.3660966157913208, 1.4668548107147217, 1.3288637399673462, 1.2815470695495605, 1.4139264822006226, 1.3829810619354248, 1.2951339483261108, 1.2497355937957764, 1.1800367832183838, 1.2333052158355713, 1.1428117752075195, 1.1831789016723633, 1.1904264688491821, 1.1026244163513184, 1.2542108297348022, 1.2131448984146118, 1.1144365072250366, 1.210911512374878, 1.1122140884399414, 1.1413675546646118, 1.1888930797576904, 1.248421311378479, 1.0857150554656982, 1.3678218126296997, 1.1891449689865112, 1.2382642030715942, 1.1100715398788452, 1.265746831893921, 1.0944952964782715, 1.0988283157348633, 1.0509830713272095, 1.111875295639038, 1.142264485359192, 0.8626812696456909, 1.1713273525238037, 1.0518640279769897, 0.9589980840682983, 1.017595887184143, 1.0297743082046509, 1.0292080640792847, 1.0208196640014648, 0.9891754388809204, 0.9372422099113464, 0.9576083421707153, 0.9769248962402344, 1.001299500465393, 0.9049217700958252, 0.9008086919784546, 0.9638864398002625, 0.9215362071990967, 0.9552983045578003, 0.9826207756996155, 0.9548539519309998, 0.9171335101127625, 1.0689035654067993, 0.8728559613227844, 0.9023128747940063, 0.9918826818466187, 1.0582376718521118, 0.847345232963562, 0.8766068816184998, 1.0181493759155273, 1.0279364585876465, 1.0272505283355713, 0.9098302125930786, 1.1224550008773804, 1.008358359336853, 0.8656930327415466, 1.0027058124542236, 0.9291003942489624, 0.8663812279701233, 0.9341189861297607, 0.9458845853805542, 0.7052664160728455, 0.9661561846733093, 0.8264095783233643, 0.9155623316764832, 0.8618954420089722, 0.809881865978241, 0.8000205755233765, 0.8204249143600464, 0.9178805351257324, 0.9622691869735718, 0.9938586950302124, 0.9750955700874329, 0.939145028591156, 0.8123230934143066, 0.8212741613388062, 0.8845038414001465, 0.9403882622718811, 1.049500823020935, 0.8790367841720581, 0.8531478047370911, 0.7423357367515564, 0.9028868675231934, 0.8066635131835938, 0.7593369483947754, 0.8573992848396301, 0.8303985595703125, 0.8370070457458496, 0.6841738820075989, 0.9901891350746155, 0.9640973210334778, 0.7309410572052002, 0.7091824412345886, 0.6867557168006897, 0.8265765309333801, 0.7159026861190796, 0.8595349192619324, 0.7783869504928589, 0.811371922492981, 0.9157472252845764, 0.6864225268363953, 0.743370532989502, 0.8986712098121643, 0.9179259538650513, 0.8901776075363159, 0.831902027130127, 0.9066917896270752, 0.833838164806366, 0.8229252696037292, 0.7498423457145691, 0.9175204038619995, 0.8134936094284058, 0.7595856785774231, 0.614568829536438, 0.7483887672424316, 0.7301159501075745, 0.8809191584587097, 0.6885015964508057, 0.805280327796936, 0.7780369520187378, 0.7304764986038208, 0.6871809959411621, 0.7811524271965027, 0.650983452796936, 0.7428043484687805, 0.6405072212219238, 0.7913560271263123, 0.6354689598083496, 0.7694313526153564, 0.7417429089546204, 0.7201295495033264, 0.81964 ...

# %%
#exp5

# %%
import tensorflow
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import tensorflow as tf
# Importing Deep Learning Libraries
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model
from keras import regularizers
from keras.preprocessing import image

#HISTOGRAM CODE
#histogram code
import matplotlib.pyplot as plt
import os

emotions = ["happy", "sadness", "anger", "disgust", "neutral", "fear", "surprise"]

folder_path = "Jaffetrainvalidation/train"
# Counting the number of images per emotion
counts = [len(os.listdir(os.path.join(folder_path, emotion))) for emotion in emotions]

# Plotting the bar chart
colors = ['red', 'yellow', 'black', 'blue', 'orange', 'green', 'pink']
plt.bar(emotions, height=counts, color=colors)
plt.ylabel('Number')
plt.xlabel('Emotions')


#plt.savefig('hostgoarm.png')
#plt.show()


# Data generators
batch_size = 64

# Data augmentation for training set
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Normalization for validation set (no augmentation)
datagen_val = ImageDataGenerator(rescale=1./255)



train_ds = datagen_train.flow_from_directory("Jaffetrainvalidation/train",
                                             target_size=(256, 256),
                                             color_mode="rgb",
                                             batch_size=batch_size,
                                             class_mode='categorical',
                                             shuffle=True)

test_ds = datagen_val.flow_from_directory("Jaffetrainvalidation/validation",
                                         target_size=(256, 256),
                                         color_mode="rgb",
                                         batch_size=batch_size,
                                         class_mode='categorical',
                                         shuffle=False)
print('Train and Validation sets have been created.')


from keras.applications.resnet import ResNet152
conv_base = ResNet152(
    weights='imagenet',
    include_top = False,
    input_shape=(256,256,3)
)


conv_base.summary()


model = Sequential()

model.add(conv_base)
model.add(Flatten())
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))
# Second fully connected layer  
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.30))

model.add(Dense(7, activation='softmax'))

# model.summary()
# Visualize the model.
#plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

conv_base.trainable = False

model.compile(optimizer = Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

print('CNN model has been created you can proceed to train you data with this model.')




# Training the model
epochs = 500

history = model.fit(x=train_ds,
                    epochs=epochs,
                    validation_data=test_ds)

# Print training history
print(history.history)

# Plotting training history
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# Found 168 images belonging to 7 classes.
# Found 45 images belonging to 7 classes.
# Train and Validation sets have been created.
# Model: "resnet152"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 262, 262, 3)          0         ['input_4[0][0]']
#
#  conv1_conv (Conv2D)         (None, 128, 128, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 128, 128, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 130, 130, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 64, 64, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 64, 64, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 64, 64, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 64, 64, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 64, 64, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 64, 64, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 64, 64, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 64, 64, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 64, 64, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 64, 64, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 32, 32, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 32, 32, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#  conv3_block2_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 32, 32, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 32, 32, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 32, 32, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 32, 32, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 32, 32, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 32, 32, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block4_out[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_2_conv[0][0]']
#  rmalization)
#
#  conv3_block5_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_2_bn[0][0]']
#  ation)
#
#  conv3_block5_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block5_2_relu[0][0]']
#  D)
#
#  conv3_block5_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block5_3_conv[0][0]']
#  rmalization)
#
#  conv3_block5_add (Add)      (None, 32, 32, 512)          0         ['conv3_block4_out[0][0]',
#                                                                      'conv3_block5_3_bn[0][0]']
#
#  conv3_block5_out (Activati  (None, 32, 32, 512)          0         ['conv3_block5_add[0][0]']
#  on)
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block5_out[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_2_conv[0][0]']
#  rmalization)
#
#  conv3_block6_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_2_bn[0][0]']
#  ation)
#
#  conv3_block6_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block6_2_relu[0][0]']
#  D)
#
#  conv3_block6_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block6_3_conv[0][0]']
#  rmalization)
#
#  conv3_block6_add (Add)      (None, 32, 32, 512)          0         ['conv3_block5_out[0][0]',
#                                                                      'conv3_block6_3_bn[0][0]']
#
#  conv3_block6_out (Activati  (None, 32, 32, 512)          0         ['conv3_block6_add[0][0]']
#  on)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block6_out[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_2_conv[0][0]']
#  rmalization)
#
#  conv3_block7_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_2_bn[0][0]']
#  ation)
#
#  conv3_block7_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block7_2_relu[0][0]']
#  D)
#
#  conv3_block7_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block7_3_conv[0][0]']
#  rmalization)
#
#  conv3_block7_add (Add)      (None, 32, 32, 512)          0         ['conv3_block6_out[0][0]',
#                                                                      'conv3_block7_3_bn[0][0]']
#
#  conv3_block7_out (Activati  (None, 32, 32, 512)          0         ['conv3_block7_add[0][0]']
#  on)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          65664     ['conv3_block7_out[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 128)          147584    ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_2_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_2_conv[0][0]']
#  rmalization)
#
#  conv3_block8_2_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_2_bn[0][0]']
#  ation)
#
#  conv3_block8_3_conv (Conv2  (None, 32, 32, 512)          66048     ['conv3_block8_2_relu[0][0]']
#  D)
#
#  conv3_block8_3_bn (BatchNo  (None, 32, 32, 512)          2048      ['conv3_block8_3_conv[0][0]']
#  rmalization)
#
#  conv3_block8_add (Add)      (None, 32, 32, 512)          0         ['conv3_block7_out[0][0]',
#                                                                      'conv3_block8_3_bn[0][0]']
#
#  conv3_block8_out (Activati  (None, 32, 32, 512)          0         ['conv3_block8_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 256)          131328    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 16, 16, 1024)         525312    ['conv3_block8_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#  conv4_block2_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 16, 16, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 16, 16, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 16, 16, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 16, 16, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 16, 16, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 16, 16, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 16, 16, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
# ...
# Epoch 418/500
# 3/3 [==============================] - 2s 727ms/step - loss: 0.6296 - accuracy: 0.7857 - val_loss: 224.6222 - val_accuracy: 0.1333
# Epoch 419/500
# 3/3 [==============================] - 2s 523ms/step - loss: 0.5151 - accuracy: 0.8095 - val_loss: 46.7033 - val_accuracy: 0.1333
# Epoch 420/500
# 3/3 [==============================] - 2s 581ms/step - loss: 0.4653 - accuracy: 0.7976 - val_loss: 36.8173 - val_accuracy: 0.1333
# Epoch 421/500
# 3/3 [==============================] - 2s 508ms/step - loss: 0.5881 - accuracy: 0.7857 - val_loss: 30.8362 - val_accuracy: 0.1333
# Epoch 422/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.4876 - accuracy: 0.7917 - val_loss: 23.1675 - val_accuracy: 0.1333
# Epoch 423/500
# 3/3 [==============================] - 2s 651ms/step - loss: 0.5018 - accuracy: 0.8274 - val_loss: 13.5758 - val_accuracy: 0.1556
# Epoch 424/500
# 3/3 [==============================] - 2s 716ms/step - loss: 0.4180 - accuracy: 0.8690 - val_loss: 7.9919 - val_accuracy: 0.2889
# Epoch 425/500
# 3/3 [==============================] - 2s 523ms/step - loss: 0.4124 - accuracy: 0.8690 - val_loss: 5.1882 - val_accuracy: 0.3333
# Epoch 426/500
# 3/3 [==============================] - 2s 522ms/step - loss: 0.6561 - accuracy: 0.7679 - val_loss: 5.0866 - val_accuracy: 0.3556
# Epoch 427/500
# 3/3 [==============================] - 2s 679ms/step - loss: 0.4990 - accuracy: 0.7976 - val_loss: 6.6745 - val_accuracy: 0.3111
# Epoch 428/500
# 3/3 [==============================] - 2s 532ms/step - loss: 0.4467 - accuracy: 0.8452 - val_loss: 6.8742 - val_accuracy: 0.3333
# Epoch 429/500
# 3/3 [==============================] - 2s 589ms/step - loss: 0.7090 - accuracy: 0.7738 - val_loss: 5.5654 - val_accuracy: 0.3333
# Epoch 430/500
# 3/3 [==============================] - 2s 508ms/step - loss: 0.4552 - accuracy: 0.8512 - val_loss: 3.9899 - val_accuracy: 0.4667
# Epoch 431/500
# 3/3 [==============================] - 2s 520ms/step - loss: 0.6624 - accuracy: 0.7798 - val_loss: 2.8677 - val_accuracy: 0.6000
# Epoch 432/500
# 3/3 [==============================] - 2s 727ms/step - loss: 0.4282 - accuracy: 0.8214 - val_loss: 3.3146 - val_accuracy: 0.4444
# Epoch 433/500
# 3/3 [==============================] - 2s 662ms/step - loss: 0.5110 - accuracy: 0.8095 - val_loss: 3.2418 - val_accuracy: 0.3556
# Epoch 434/500
# 3/3 [==============================] - 2s 678ms/step - loss: 0.4265 - accuracy: 0.8690 - val_loss: 2.9239 - val_accuracy: 0.4000
# Epoch 435/500
# 3/3 [==============================] - 2s 678ms/step - loss: 0.4196 - accuracy: 0.8333 - val_loss: 3.4101 - val_accuracy: 0.3778
# Epoch 436/500
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5292 - accuracy: 0.8095 - val_loss: 3.9433 - val_accuracy: 0.3778
# Epoch 437/500
# 3/3 [==============================] - 2s 643ms/step - loss: 0.5090 - accuracy: 0.8214 - val_loss: 4.4546 - val_accuracy: 0.3333
# Epoch 438/500
# 3/3 [==============================] - 2s 494ms/step - loss: 0.4480 - accuracy: 0.8690 - val_loss: 5.1283 - val_accuracy: 0.2667
# Epoch 439/500
# 3/3 [==============================] - 2s 503ms/step - loss: 0.5597 - accuracy: 0.7798 - val_loss: 4.6476 - val_accuracy: 0.2889
# Epoch 440/500
# 3/3 [==============================] - 2s 507ms/step - loss: 0.3278 - accuracy: 0.8690 - val_loss: 4.0006 - val_accuracy: 0.3778
# Epoch 441/500
# 3/3 [==============================] - 2s 657ms/step - loss: 0.4863 - accuracy: 0.8095 - val_loss: 3.0839 - val_accuracy: 0.4667
# Epoch 442/500
# 3/3 [==============================] - 2s 697ms/step - loss: 0.5672 - accuracy: 0.7798 - val_loss: 2.3496 - val_accuracy: 0.5111
# Epoch 443/500
# 3/3 [==============================] - 2s 726ms/step - loss: 0.3676 - accuracy: 0.8631 - val_loss: 2.2004 - val_accuracy: 0.6222
# Epoch 444/500
# 3/3 [==============================] - 2s 724ms/step - loss: 0.4894 - accuracy: 0.8095 - val_loss: 2.5789 - val_accuracy: 0.6222
# Epoch 445/500
# 3/3 [==============================] - 2s 747ms/step - loss: 0.5866 - accuracy: 0.7738 - val_loss: 2.9228 - val_accuracy: 0.5556
# Epoch 446/500
# 3/3 [==============================] - 2s 734ms/step - loss: 0.5190 - accuracy: 0.8095 - val_loss: 2.8577 - val_accuracy: 0.5778
# Epoch 447/500
# 3/3 [==============================] - 2s 606ms/step - loss: 0.4492 - accuracy: 0.8095 - val_loss: 2.8013 - val_accuracy: 0.6000
# Epoch 448/500
# 3/3 [==============================] - 2s 784ms/step - loss: 0.5700 - accuracy: 0.8095 - val_loss: 2.4867 - val_accuracy: 0.7111
# Epoch 449/500
# 3/3 [==============================] - 2s 735ms/step - loss: 0.4230 - accuracy: 0.8452 - val_loss: 2.4784 - val_accuracy: 0.7333
# Epoch 450/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.4377 - accuracy: 0.8333 - val_loss: 2.7410 - val_accuracy: 0.6667
# Epoch 451/500
# 3/3 [==============================] - 2s 607ms/step - loss: 0.4443 - accuracy: 0.8274 - val_loss: 2.9154 - val_accuracy: 0.6667
# Epoch 452/500
# 3/3 [==============================] - 2s 747ms/step - loss: 0.4106 - accuracy: 0.8631 - val_loss: 2.7646 - val_accuracy: 0.6444
# Epoch 453/500
# 3/3 [==============================] - 2s 780ms/step - loss: 0.5286 - accuracy: 0.7976 - val_loss: 2.4661 - val_accuracy: 0.6889
# Epoch 454/500
# 3/3 [==============================] - 2s 577ms/step - loss: 0.4846 - accuracy: 0.8155 - val_loss: 2.3601 - val_accuracy: 0.6222
# Epoch 455/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.4640 - accuracy: 0.8095 - val_loss: 2.3519 - val_accuracy: 0.5333
# Epoch 456/500
# 3/3 [==============================] - 2s 735ms/step - loss: 0.4330 - accuracy: 0.8333 - val_loss: 2.1345 - val_accuracy: 0.5333
# Epoch 457/500
# 3/3 [==============================] - 2s 582ms/step - loss: 0.5901 - accuracy: 0.7619 - val_loss: 1.9567 - val_accuracy: 0.6222
# Epoch 458/500
# 3/3 [==============================] - 2s 602ms/step - loss: 0.3505 - accuracy: 0.8869 - val_loss: 2.6165 - val_accuracy: 0.5333
# Epoch 459/500
# 3/3 [==============================] - 2s 744ms/step - loss: 0.4927 - accuracy: 0.8333 - val_loss: 3.1497 - val_accuracy: 0.4667
# Epoch 460/500
# 3/3 [==============================] - 2s 593ms/step - loss: 0.4410 - accuracy: 0.8512 - val_loss: 3.2632 - val_accuracy: 0.5333
# Epoch 461/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.3886 - accuracy: 0.8810 - val_loss: 3.4197 - val_accuracy: 0.4889
# Epoch 462/500
# 3/3 [==============================] - 2s 726ms/step - loss: 0.4479 - accuracy: 0.8214 - val_loss: 3.6535 - val_accuracy: 0.4889
# Epoch 463/500
# 3/3 [==============================] - 2s 520ms/step - loss: 0.4320 - accuracy: 0.8333 - val_loss: 3.4976 - val_accuracy: 0.5111
# Epoch 464/500
# 3/3 [==============================] - 2s 493ms/step - loss: 0.5649 - accuracy: 0.7798 - val_loss: 3.5738 - val_accuracy: 0.4889
# Epoch 465/500
# 3/3 [==============================] - 2s 700ms/step - loss: 0.4766 - accuracy: 0.8214 - val_loss: 3.0284 - val_accuracy: 0.5111
# Epoch 466/500
# 3/3 [==============================] - 2s 532ms/step - loss: 0.4190 - accuracy: 0.8512 - val_loss: 2.7835 - val_accuracy: 0.5556
# Epoch 467/500
# 3/3 [==============================] - 2s 533ms/step - loss: 0.5166 - accuracy: 0.8214 - val_loss: 2.7913 - val_accuracy: 0.5556
# Epoch 468/500
# 3/3 [==============================] - 2s 550ms/step - loss: 0.5240 - accuracy: 0.8036 - val_loss: 2.1946 - val_accuracy: 0.5778
# Epoch 469/500
# 3/3 [==============================] - 2s 537ms/step - loss: 0.4636 - accuracy: 0.8274 - val_loss: 2.0682 - val_accuracy: 0.5556
# Epoch 470/500
# 3/3 [==============================] - 2s 519ms/step - loss: 0.4168 - accuracy: 0.8393 - val_loss: 1.8716 - val_accuracy: 0.6222
# Epoch 471/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.4602 - accuracy: 0.8214 - val_loss: 2.4848 - val_accuracy: 0.5778
# Epoch 472/500
# 3/3 [==============================] - 2s 663ms/step - loss: 0.4613 - accuracy: 0.8214 - val_loss: 3.0766 - val_accuracy: 0.5333
# Epoch 473/500
# 3/3 [==============================] - 2s 552ms/step - loss: 0.5015 - accuracy: 0.8274 - val_loss: 3.7226 - val_accuracy: 0.4889
# Epoch 474/500
# 3/3 [==============================] - 2s 522ms/step - loss: 0.4553 - accuracy: 0.8155 - val_loss: 5.0714 - val_accuracy: 0.3778
# Epoch 475/500
# 3/3 [==============================] - 2s 570ms/step - loss: 0.4865 - accuracy: 0.7976 - val_loss: 5.6544 - val_accuracy: 0.4000
# Epoch 476/500
# 3/3 [==============================] - 2s 672ms/step - loss: 0.4391 - accuracy: 0.8690 - val_loss: 5.1235 - val_accuracy: 0.4222
# Epoch 477/500
# 3/3 [==============================] - 2s 714ms/step - loss: 0.4433 - accuracy: 0.8274 - val_loss: 4.4119 - val_accuracy: 0.4889
# Epoch 478/500
# 3/3 [==============================] - 2s 500ms/step - loss: 0.3936 - accuracy: 0.8571 - val_loss: 3.6495 - val_accuracy: 0.5778
# Epoch 479/500
# 3/3 [==============================] - 2s 496ms/step - loss: 0.3919 - accuracy: 0.8810 - val_loss: 3.1965 - val_accuracy: 0.6444
# Epoch 480/500
# 3/3 [==============================] - 2s 656ms/step - loss: 0.4930 - accuracy: 0.8274 - val_loss: 3.0677 - val_accuracy: 0.6000
# Epoch 481/500
# 3/3 [==============================] - 2s 527ms/step - loss: 0.4298 - accuracy: 0.8155 - val_loss: 3.2822 - val_accuracy: 0.5778
# Epoch 482/500
# 3/3 [==============================] - 2s 495ms/step - loss: 0.3823 - accuracy: 0.8690 - val_loss: 3.8557 - val_accuracy: 0.4889
# Epoch 483/500
# 3/3 [==============================] - 2s 571ms/step - loss: 0.4610 - accuracy: 0.8036 - val_loss: 4.5640 - val_accuracy: 0.4667
# Epoch 484/500
# 3/3 [==============================] - 2s 522ms/step - loss: 0.4743 - accuracy: 0.8155 - val_loss: 3.8936 - val_accuracy: 0.4889
# Epoch 485/500
# 3/3 [==============================] - 2s 512ms/step - loss: 0.3769 - accuracy: 0.8393 - val_loss: 3.8696 - val_accuracy: 0.4000
# Epoch 486/500
# 3/3 [==============================] - 2s 561ms/step - loss: 0.5094 - accuracy: 0.7976 - val_loss: 3.2288 - val_accuracy: 0.5111
# Epoch 487/500
# 3/3 [==============================] - 2s 506ms/step - loss: 0.5496 - accuracy: 0.7976 - val_loss: 2.8350 - val_accuracy: 0.6222
# Epoch 488/500
# 3/3 [==============================] - 2s 525ms/step - loss: 0.4213 - accuracy: 0.8512 - val_loss: 3.0919 - val_accuracy: 0.5556
# Epoch 489/500
# 3/3 [==============================] - 2s 506ms/step - loss: 0.4837 - accuracy: 0.8214 - val_loss: 3.4521 - val_accuracy: 0.5111
# Epoch 490/500
# 3/3 [==============================] - 2s 711ms/step - loss: 0.5649 - accuracy: 0.8036 - val_loss: 3.1589 - val_accuracy: 0.4889
# Epoch 491/500
# 3/3 [==============================] - 2s 546ms/step - loss: 0.4657 - accuracy: 0.8393 - val_loss: 2.7068 - val_accuracy: 0.5333
# Epoch 492/500
# 3/3 [==============================] - 2s 501ms/step - loss: 0.4480 - accuracy: 0.8631 - val_loss: 3.1422 - val_accuracy: 0.4444
# Epoch 493/500
# 3/3 [==============================] - 2s 725ms/step - loss: 0.3867 - accuracy: 0.8869 - val_loss: 3.6378 - val_accuracy: 0.4444
# Epoch 494/500
# 3/3 [==============================] - 2s 595ms/step - loss: 0.4394 - accuracy: 0.8274 - val_loss: 4.1341 - val_accuracy: 0.4222
# Epoch 495/500
# 3/3 [==============================] - 2s 523ms/step - loss: 0.4992 - accuracy: 0.8274 - val_loss: 4.6241 - val_accuracy: 0.4222
# Epoch 496/500
# 3/3 [==============================] - 2s 531ms/step - loss: 0.5727 - accuracy: 0.8155 - val_loss: 5.0031 - val_accuracy: 0.4000
# Epoch 497/500
# 3/3 [==============================] - 2s 516ms/step - loss: 0.3557 - accuracy: 0.8929 - val_loss: 5.0456 - val_accuracy: 0.4000
# Epoch 498/500
# 3/3 [==============================] - 2s 512ms/step - loss: 0.6184 - accuracy: 0.7560 - val_loss: 4.8506 - val_accuracy: 0.4444
# Epoch 499/500
# 3/3 [==============================] - 2s 542ms/step - loss: 0.5433 - accuracy: 0.7976 - val_loss: 3.8792 - val_accuracy: 0.4000
# Epoch 500/500
# 3/3 [==============================] - 2s 657ms/step - loss: 0.4334 - accuracy: 0.8393 - val_loss: 2.9333 - val_accuracy: 0.5333
# {'loss': [3.2938525676727295, 2.7073276042938232, 2.4233570098876953, 2.2935631275177, 2.262782573699951, 2.141268253326416, 2.2432124614715576, 2.0522375106811523, 2.1347548961639404, 2.1274585723876953, 2.102634906768799, 2.069352149963379, 1.929692029953003, 1.8753211498260498, 2.017923593521118, 2.2185609340667725, 2.018326997756958, 1.9383628368377686, 2.0006117820739746, 1.946955680847168, 1.794525146484375, 1.6934785842895508, 1.646971583366394, 1.6070455312728882, 1.7480850219726562, 1.6622003316879272, 1.616356611251831, 1.7992055416107178, 1.630219578742981, 1.6722207069396973, 1.7636624574661255, 1.6909452676773071, 1.7225029468536377, 1.507049322128296, 1.6762986183166504, 1.540802240371704, 1.5635472536087036, 1.5844553709030151, 1.661346435546875, 1.4449851512908936, 1.43966805934906, 1.4315296411514282, 1.3483681678771973, 1.4301568269729614, 1.554481863975525, 1.3951691389083862, 1.463378667831421, 1.3314363956451416, 1.150591254234314, 1.3010190725326538, 1.2756521701812744, 1.2579984664916992, 1.4897371530532837, 1.2638680934906006, 1.3338056802749634, 1.3847471475601196, 1.4256861209869385, 1.338592290878296, 1.4108301401138306, 1.3896993398666382, 1.2365143299102783, 1.295486569404602, 1.1548166275024414, 1.118355631828308, 1.2686716318130493, 1.2488924264907837, 1.162024736404419, 1.1910252571105957, 1.171397089958191, 1.1880296468734741, 1.2445054054260254, 1.0227539539337158, 1.1452730894088745, 1.179048776626587, 1.1363239288330078, 1.1238811016082764, 1.1533159017562866, 1.253637433052063, 1.2992408275604248, 1.1887342929840088, 1.0469859838485718, 1.129563570022583, 1.171406865119934, 1.289139747619629, 1.0187864303588867, 1.0984461307525635, 1.0730310678482056, 1.1610972881317139, 1.1308990716934204, 1.0851857662200928, 1.1300686597824097, 0.9992907643318176, 1.0624878406524658, 1.0288481712341309, 0.9448412656784058, 1.1017649173736572, 0.9876327514648438, 1.003509283065796, 1.031076192855835, 0.9966784715652466, 1.0922629833221436, 0.9786463379859924, 0.9827710390090942, 0.999230146408081, 1.1877985000610352, 1.1239992380142212, 1.0684586763381958, 1.0100839138031006, 1.0274862051010132, 1.1185017824172974, 0.910158634185791, 0.9039693474769592, 0.9874686002731323, 1.035805106163025, 0.9812062382698059, 0.9541789293289185, 0.9158276319503784, 1.0635381937026978, 1.020730972290039, 0.9334462285041809, 0.9796503782272339, 0.8867093920707703, 0.811491847038269, 1.052770733833313, 1.0718817710876465, 0.9376264214515686, 1.0669718980789185, 0.8868335485458374, 0.994411826133728, 0.8542740941047668, 0.9525160789489746, 0.9337822794914246, 0.8692333698272705, 0.8685696721076965, 0.8482630848884583, 0.757777988910675, 0.9179943799972534, 0.8331071734428406, 0.824248194694519, 0.8506488800048828, 0.7901108264923096, 0.8875031471252441, 0.9209120869636536, 0.9246378540992737, 0.8673270344734192, 0.8340463042259216, 0.8266204595565796, 0.898413896560669, 0.9320498108863831, 0.8381049633026123, 1.025090217590332, 0.8332290649414062, 0.886873722076416, 0.8367404937744141, 0.984165370464325, 0.6842795610427856, 0.9059937596321106, 0.8214092254638672, 0.7740230560302734, 0.7709929943084717, 0.815174400806427, 0.7256634831428528, 0.7274100184440613, 0.8054941296577454, 0.7890368103981018, 0.7624152898788452, 0.6404943466186523, 0.6905568242073059, 0.7690414190292358, 0.9859029054641724, 0.7791450023651123, 0.8027463555335999, 0.6760991811752319, 0.8766247034072876, 0.8514405488967896, 0.7486209869384766, 0.6534889936447144, 0.7325703501701355, 0.631769061088562, 0.714450478553772, 0.6531971096992493, 0.751327395439148, 0.7469512224197388, 0.7052512168884277, 0.7603740692138672, 0.736850917339325, 0.7610722184181213, 0.7350444197654724, 0.6612571477890015, 0.7772030830383301, 0.686822235584259, 0.693915843963623, 0.8694761395454407, 0.7102556824684143, 0.6744062900543213, 0.7688784003257751, 0.736221969127655, 0.7049328088760376, 0.7000373601913452, 0.6078579425811768, 0.6117329001426697, 0.6902831792831421, 0.6584 ...
